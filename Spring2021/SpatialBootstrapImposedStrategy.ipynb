# %% [markdown]
# <p align="center">
#     <img src="https://github.com/GeostatsGuy/GeostatsPy/blob/master/TCG_color_logo.png?raw=true" width="220" height="240" />
#
# </p>
#
# ## Subsurface Data Analytics
#
# ## Sequential Gaussian Simulation with Imposed Strategy Bootstrap
#
# #### Adrian Salinas, Petroleum Engineering Student, The University of Texas at Austin
#
# ##### [LinkedIn](https://www.linkedin.com/in/adrian-salinas/) | [GitHub](https://github.com/adriansalinas98)
# ##### Email: AdrianSalinas98@gmail.com
#
# #### Supervised by:
#
# #### Michael Pyrcz, Associate Professor, University of Texas at Austin
#
# ##### [Twitter](https://twitter.com/geostatsguy) | [GitHub](https://github.com/GeostatsGuy) | [Website](http://michaelpyrcz.com) | [GoogleScholar](https://scholar.google.com/citations?user=QVZ20eQAAAAJ&hl=en&oi=ao) | [Book](https://www.amazon.com/Geostatistical-Reservoir-Modeling-Michael-Pyrcz/dp/0199731446) | [YouTube](https://www.youtube.com/channel/UCLqEr-xV-ceHdXXXrTId5ig)  | [LinkedIn](https://www.linkedin.com/in/michael-pyrcz-61a648a1) | [GeostatsPy](https://github.com/GeostatsGuy/GeostatsPy)
#
#
#
#
# ### Sequential Gausssian Simulation
#
# #### Reasoning for building a SGSIM model:
# - We want to have a complete spatial model that honors the global distribution and variogram of our data.
#
# Kriging gives the most likely value at each location in a spatial model, and at distances greater than the range, simple kriging assusmes those locations are the global mean of the data. This effect often misses the
# short-range variability and heterogeneity in geospatial data.
# - SGSIM corrects for Kriging's low model variance by working in gaussian space, where high values and low values tend not to bunch up. (honors global distribution / histogram)
# - SGSIM corrects for Kriging's continuous variogram or 'smoothness' (honors spatial variablity)
#
# With this full model of heterogeneity, We are going to compare the outcomes between two methods of Bootstrap.
#
# #### Method 1:  Journelian Bootstrap With Constant Drilling Locations:
#
# Bootstrap is a means to build an uncertainty distribution for any statsitic by leveraging the scarcity of data. It performs mulitple monte carlo simulations based on the number of available data to build an uncertainty model.
#
# - Using our full SGSIM models, we randomly drill n wells using montecarlo simulation in our area of interest. From these wells, take the porosity of each well and store the porosity in a total distribution that will be used for bootstrap.
# - Repeat this drilling strategy by generating more realizations (SGSIM #2,#3,#n), but keep the well locations the same across all SGSIM models and record the porosity for all wells accross every SGSIM realization. For example you want to drill 50 wells, and will make 5 SGSIM models. Your total distibution will have 250 samples of porosity.
# - Once you have your total distribution of porosity, perform bootstrap on the data by randomly sampling with replacement 250 times. This is 1 realization. Take the mean of each realization as a single value and store it in the global distribution of mean porosity. Repeat for as many times as you need to build a good measure of uncertainty/good distribution of mean porosity.
#
# #### Method 2: Journelian Bootstrap with Imposed Strategy  Annulur Rejection Filter:
#
# This method will add a stategy to the spatial bootsrap process in method 1. The strategy will implement a predetermined decision criteria that dictates the sampling process that gathers samples for bootstrap using an isotropic SGSIM model.
#
# ##### Strategy:
#
# - Drill a random well from our model, this is well #1.
# #### If this well is a 'good well' or it exceeds a porosity value determined to be sufficiently high:
# -  Drill another well (well #2) located in the 'annulus' of well #1. Where the annulus is the region surrounding the well defined as the difference between determined radii R1, R2 (R1 > R2). Our intention with a 'good well' outcome is to drill a well close to well #1 (within R1), but not too close (inside R2).
# #### If this well is a 'bad well' or its porosity value is lower than a value determined to be sufficiently low:
# - Drill well #2 outside of R1 of well #1. Our intention with a 'bad well' outcome is to drill a well far enough away from a bad well to increase the likelihood of drilling a better well with the next drill.
#
# ### Assumptions:
# With a basic drilling strategy in place, lets discuss some key assumptions that we will make:
#
# #### How close is close? - Determining R1 & R2
# - In spatial context, We want to honor the variogram of our generated SGSIM model. We do this by assuming R1, the radius of distance that defines the area of 'close' new drills, is equal to the major axis range of the variogram used to generate the SGSIM model. The range of a variogram is the maximum distance away from a known data location where we can expect to still have information from the known data location to make a prediction. Predicting outside of this range would be a naive prediction with regards to the information from the known data location. This is why when we have a good well we drill within the range/R1 to keep the information from the good well, and when we drill a bad well, we drill outside the range/R1 to miminimze the influence of the bad well on our next drill.
#
# - We never want to drill too close to our previous drill becuase its likely that we could get stuck drilling the same area because the subsequent well likely be good. This also doesnt make practical sense in real-world applications where operators tend to maximize the productive field by drilling at strategically spaced locations. We can determine the minimum distance to avoid drilling a subsequent well as the minor axis range of the variogram model of our raw data. No matter which azimuth you drill a new well along within R2, your data will still share information from your previous well, so we will drill outside of this radius always.
#
# #### Method 2: Journelian Bootstrap with Imposed Strategy  Elliptical Rejection Filter:
#
# We will apply the same strategy as the annular rejection filter, but instead build an anistropic SGSIM model where we can use a full spatial ellipse from variogram calcualtions to filter good well samples.
#
# Finally we will compare Method 1's uncertainty in porosity distribution to that of both of Method 2's Rejection filters.

# %%
import os                                                  
import numpy as np                                        
import pandas as pd                                       
import matplotlib.pyplot as plt   
from matplotlib.path import Path


import pprint
import math
from math import pi
import scipy
import random
from numpy.random import randn
from scipy.stats import norm
from IPython.display import Image
from ipywidgets import interactive                      # widgets and interactivity
from ipywidgets import widgets                            
from ipywidgets import Layout
from ipywidgets import Label
from ipywidgets import VBox, HBox
import itertools as it                               #flattens lists for widgets
from scipy.interpolate import griddata
from matplotlib.patches import Ellipse
from matplotlib.patches import Circle

# %%
import geostatspy.geostats as geostats
import geostatspy.GSLIB as GSLIB

# %% [markdown]
# Set working directory

# %%
# os.chdir("C:\Users\admin1\Desktop\resources\CSE Project")

# %% [markdown]
# Lets start by creating a Gaussian distrubted porosity dataset.

# %%
porosity  = np.array([])
normal = pd.read_csv('norm.csv')
por = np.array(normal['p'])
count = np.array(normal['count'])
c=0
for i in range(0,len(por)):
    c=0
    while c <= count[i]:
        c += 1
        porosity = np.append(porosity,por[i])
por_samples = np.array([])
for i in range(100):
    index = np.random.randint(0,len(porosity))
    por_samples = np.append(por_samples,porosity[index])

df_iso = pd.DataFrame(por_samples,columns = ['porosity'])
# porosity.describe()
df_iso.describe()
# Out:
#          porosity
# count  100.000000
# mean     0.156600
# std      0.028230
# min      0.099888
# 25%      0.135223
# 50%      0.157307
# 75%      0.176815
# max      0.208837

# %%
plt.hist(df_iso)
# Out:
# (array([ 6.,  5., 12., 12., 10., 10., 17., 14.,  6.,  8.]),
#  array([0.09988828, 0.1107831 , 0.12167793, 0.13257275, 0.14346758,
#         0.1543624 , 0.16525722, 0.17615205, 0.18704687, 0.1979417 ,
#         0.20883652]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# To make this Spatial data, lets assign X and Y locations for each porosity location equally spaced across 10,000m. Here, every well locaiton is 1000 meters apart.
#
# Let's visualize the data.

# %%
x = np.tile(np.linspace(0,10000,10), 10)
y = np.repeat(np.linspace(10,10000,10), 10)
df_iso['X'] = x
df_iso['Y'] = y

GSLIB.locmap_st(df_iso,'X','Y','porosity',0,10000,0,10000,.05,.3,'Porosity','X (m)','Y (m)','Porosity Map',plt.cm.plasma)
# Out:
# C:\Users\admin1\anaconda3\lib\site-packages\geostatspy\GSLIB.py:323: MatplotlibDeprecationWarning:
# The 'verts' parameter of scatter() was deprecated in Matplotlib 3.2 and will be removed two minor releases later. If any parameter follows 'verts', they should be passed as keyword, not positionally.
#   im = plt.scatter(

# %% [markdown]
# ## Variogram
#
# For now lets work with our isotropic, Gaussian distrubted porosity data. This means we can use an isotropic variogram in our SGSIM model:
# - hmin = hmax
#
# Lets determine what these values are by constructing a variogram

# %%
tmin = -9999.; tmax = 9999.                             # no trimming of our data 
lag_dist = 1000.0; lag_tol = 1000.0; nlag = 20;     # maximum lag is 1000m, log_tol > 1/2 lag distance (smoothing)
bandh = 9999.9; atol = 25                             # give bandwidth no effect: directional variograms
isill = 1                                               # standardize sill(equal to variance = 1 in normal trans)
azi_mat = [0,22.5,45,67.5,90,112.5,135,157.5]           # directions in azimuth to consider

#Store results in these arrays
lag = np.zeros((len(azi_mat),nlag+2))
variogram = np.zeros((len(azi_mat),nlag+2))
z = np.zeros((len(azi_mat),nlag+2))

for azi in range(0,len(azi_mat)):                      # Loop over all directions
    lag[azi,:], variogram[azi,:], z[azi,:] = geostats.gamv(df_iso,"X","Y","porosity",tmin,tmax,
                                                                lag_dist,lag_tol,nlag,azi_mat[azi],
                                                                atol,bandh,isill)
#visualize each variogram 
    plt.subplot(4,2,azi+1)
    plt.plot(lag[azi,:],variogram[azi,:],'o',color = 'r',label = 'Azimuth ' +str(azi_mat[azi]))
    plt.plot([0,10000],[1.0,1.0],color = 'black')
    plt.xlabel(r'Lag Distance $\bf(h)$, (m)')
    plt.ylabel(r'$\gamma \bf(h)$')
    plt.title('Directional NSCORE Porosity Variogram')
    plt.xlim([0,10000])
    plt.ylim([0,1.8])
    plt.legend(loc='upper left')
    plt.grid(True)

plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=4.2, wspace=0.2, hspace=0.3)
plt.show()

# %% [markdown]
# We see that in most directions, our data set has the same range of 1000m, which is expected in a uniformly spaced data set that was spaced the same distance. We should only retain information about a point that is 1000m away which makes sense if that is the only distance at which points exist.
#
# We know have our variogram model parameters to input to our SGSIM model.

# %% [markdown]
# ## SGSIM Model
# Lets build a SGSIM model using simple kriging estimator, to do this we will implement the SGSIM fuction from
# geostatspy library and set the fuction parameter 'ktype' = 0
#
# - By using simple kriging we are not constraining the weights assigned to data to model (as done in ordinary kriging where the sum of weights = 1 and the global mean of data does not need to be known, local mean is used instead), and we are working with the residual from the mean. Doing so assumes stationarity in our data i.e. no trends in the data.

# %%
# we are setting our working variables that will be inputs to our sgsim fuction
nx = 100; ny = 100; xsiz = 100.0; ysiz = 100.0; xmn = 5.0; ymn = 5.0; nxdis = 1; nydis = 1
ndmin = 0; ndmax = 10; radius = 400; skmean = 0

#instatiation of a variogram model with necessary function parameters nugget effect, major & minor ranges, 
#azimuth, etc. 
vario = GSLIB.make_variogram(nug=0.0,nst=1,it1=1,cc1=1.0,azi1=0.0,hmaj1=1000,hmin1=1000)

#trimming limits (no effect on data)
tmin = 0; tmax = 10000

#SGSIM model
sim_sk = geostats.sgsim(df_iso,'X','Y','porosity',wcol=-1,scol=-1,tmin=tmin,tmax=tmax,itrans=1,ismooth=0,dftrans=0,tcol=0,
            twtcol=0,zmin=0.0,zmax=0.3,ltail=1,ltpar=0.0,utail=1,utpar=0.3,nsim=1,
            nx=nx,xmn=xmn,xsiz=xsiz,ny=ny,ymn=ymn,ysiz=ysiz,seed=73073,
            ndmin=ndmin,ndmax=ndmax,nodmax=10,mults=0,nmult=2,noct=-1,radius=radius,radius1=1,sang1=0,
            mxctx=10,mxcty=10,ktype=0,colocorr=0.0,sec_map=0,vario=vario)

#visualize created SGSIM model
xmin = 0.0; xmax = 10000.0; ymin = 0.0; ymax = 10000.0; cmap = plt.cm.inferno
plt.subplot(111)  
GSLIB.locpix_st(sim_sk,xmin,xmax,ymin,ymax,xsiz,0.0,0.30,df_iso,'X','Y','porosity',
                'Sequential Gaussian Simulation - Simple Kriging','X(m)','Y(m)','Porosity',cmap)
plt.subplots_adjust(left=0.0, bottom=0.0, right=1.25, top=1.25, wspace=0.2, hspace=0.2)
print('simsk ', len(sim_sk))
# Out:
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1566
#                  Weighted Variance             = 0.0008
#                  Weighted Transformed Average  = 0.0326
#                  Weighted Transformed Variance = 0.9837
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = 0.0485 (close to 0.0?)
#                                    variance = 0.8061 (close to gammabar(V,V)? approx. 1.0)
# C:\Users\admin1\anaconda3\lib\site-packages\geostatspy\GSLIB.py:700: MatplotlibDeprecationWarning:
# The 'verts' parameter of scatter() was deprecated in Matplotlib 3.2 and will be removed two minor releases later. If any parameter follows 'verts', they should be passed as keyword, not positionally.
#   plt.scatter(
# simsk  100

# %% [markdown]
# ### Method 1:  Journelian Bootstrap
#
# Before we build multiple SGSIM models and perform bootstrap, lets demonstate the process for a single SGSIM model.
#
# - We want to sample from our exhaustive SGSIM model to gather the distrubution of 'wells' that will each have a porosity value. To do this, we can flatten our model and randomly sample from the 1D-array with as many 'wells' as we want to drill (say 50).
# - Now to build the uncertainty model, we perform bootsrap on the 50 samples, randomly sampling 50 times with replacement to build a single realization. We repeat this enough times to build an uncertainty model of mean porosity across our 50 wells.

# %%
sample_array = sim_sk.flatten()

wells = np.array([])                               #an array of random samples of our SGSIM model

for i in range(0,50):                              #want to drill 50 wells
    index = np.random.randint(0,len(sample_array)) #want to pull from entire 10,000 data points of SGSIM model
    wells = np.append(wells,sample_array[index])

mean_por = np.array([])
n = 0
while n < 100:                                     #n realizations (number of times we drill 50 wells)
    n+=1
    samples = np.array([])
    for i in range(0,len(wells)):
        index = np.random.randint(0,len(wells))
        samples = np.append(samples,wells[index])  #builds 1 full realization of 50 wells
    mean = np.mean(samples)
    mean_por = np.append(mean_por,mean)

#Visualize uncertainty distribution in single SGSIM model:

bins = 30
plt.subplot(1,1,1)
n, bins,patches = plt.hist(mean_por,bins,facecolor = 'r',density=True)
plt.xlabel('Mean Porosity' )
plt.ylabel('Count')
plt.title('Uncertainty in Mean Porosity of well locations')
# Out:
# Text(0.5, 1.0, 'Uncertainty in Mean Porosity of well locations')

# %% [markdown]
# ## Journelian Bootstrap: Constant Drilling Locations
# Now that we understand bootstrap in a single SGSIM model, lets follow the Journelian approach where we build multiple SGSIM models that all contribute to the total porosity distribution that we will perform bootstrap on. We need to change the random number seed for the SGSIM model to ensure we get a new model every time we perform a bootstrap realization.
#
# Its important that we keep the drill locations the same accross our SGSIM models for this approach.

# %%
SGSIMreals = 0   #of SGSIM Models for a distribution
ndata = 50
sample_array = sim_sk.flatten()

#take the SGSIM code(minus visualization) from above and work it into a loop for automation.

wells = np.array([]) 
drill_loc = np.array([])
seeds = 0
for i in range(0,50):                                   #drill 50 wells in the same location so we store this in 'drill_loc'
    index = int(np.random.randint(0,len(sample_array))) #pull from entire 10,000 data points of SGSIM model
    drill_loc = np.append(drill_loc,index)

while SGSIMreals < 5:           #number of isotropic SGSIM models for global distribution
    SGSIMreals += 1
    
    nx = 100; ny = 100; xsiz = 100.0; ysiz = 100.0; xmn = 5.0; ymn = 5.0; nxdis = 1; nydis = 1
    ndmin = 0; ndmax = 10; radius = 400; skmean = 0
    vario = GSLIB.make_variogram(nug=0.0,nst=1,it1=1,cc1=1.0,azi1=45.0,hmaj1=1000,hmin1=1000)
    tmin = -999; tmax = 999

#SGSIM model
    seeds += 1
    sim_sk = geostats.sgsim(df_iso,'X','Y','porosity',wcol=-1,scol=-1,tmin=tmin,tmax=tmax,itrans=1,ismooth=0,dftrans=0,tcol=0,
                twtcol=0,zmin=0.0,zmax=0.3,ltail=1,ltpar=0.0,utail=1,utpar=0.3,nsim=1,
                nx=nx,xmn=xmn,xsiz=xsiz,ny=ny,ymn=ymn,ysiz=ysiz,seed=seeds,
                ndmin=ndmin,ndmax=ndmax,nodmax=10,mults=0,nmult=2,noct=-1,radius=radius,radius1=1,sang1=0,
                mxctx=10,mxcty=10,ktype=0,colocorr=0.0,sec_map=0,vario=vario)

    
    sample_array = sim_sk.flatten()
    sampy = sample_array[50]
    print('sampy: ', sampy)
    print('len', len(sample_array))
    print('drill_loc ',drill_loc)

    

    for i in range(0,len(drill_loc)):
        index1 = int(drill_loc[i])
        wells = np.append(wells,sample_array[index1])
    print('# wells ',len(wells))        

        
# by now we have our global distribution of wells drilled in multiple SGSIM models at the same locations 
# now perform bootstrap

mean_por_standard = np.array([])
n = 0
while n < 100:                                     #n realizations (number of times sample 250 wells)
    n+=1
    samples = np.array([])
    for i in range(0,len(wells)):
        index = np.random.randint(0,len(wells))
        samples = np.append(samples,wells[index])  #builds 1 full realization of all wells
    mean = np.mean(samples)
    mean_por_standard = np.append(mean_por_standard,mean)
    
print('bins ',len(mean_por_standard))
#Visualize
    
bins = 25
plt.subplot(1,1,1)
n, bins,patches = plt.hist(mean_por_standard,bins,facecolor = 'r',density=True)
plt.xlabel('Mean Porosity')
plt.ylabel('Count')
plt.title('Journelian Bootstrap')
# Out:
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1566
#                  Weighted Variance             = 0.0008
#                  Weighted Transformed Average  = 0.0326
#                  Weighted Transformed Variance = 0.9837
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = 0.0096 (close to 0.0?)
#                                    variance = 0.8576 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.20883652100000002
# len 10000
# drill_loc  [1147. 6659. 2215.  166. 6136. 4674. 9688. 2216.  427.  218. 7510. 6777.
#  2595. 8999. 1390. 5316. 7160. 8631. 9357. 7389. 9967. 4070. 7365. 8513.
#    24. 1166. 1326. 7494.  596.  216. 1908. 3131.  626. 4662. 7548. 8013.
#  3062. 9460.  195.  863. 8700. 2733. 1352. 4359. 1981. 3587. 3701. 9692.
#  2789. 6063.]
# # wells  50
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1566
#                  Weighted Variance             = 0.0008
#                  Weighted Transformed Average  = 0.0326
#                  Weighted Transformed Variance = 0.9837
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = 0.0329 (close to 0.0?)
#                                    variance = 0.8196 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.16235571915504562
# len 10000
# drill_loc  [1147. 6659. 2215.  166. 6136. 4674. 9688. 2216.  427.  218. 7510. 6777.
#  2595. 8999. 1390. 5316. 7160. 8631. 9357. 7389. 9967. 4070. 7365. 8513.
#    24. 1166. 1326. 7494.  596.  216. 1908. 3131.  626. 4662. 7548. 8013.
#  3062. 9460.  195.  863. 8700. 2733. 1352. 4359. 1981. 3587. 3701. 9692.
#  2789. 6063.]
# # wells  100
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1566
#                  Weighted Variance             = 0.0008
#                  Weighted Transformed Average  = 0.0326
#                  Weighted Transformed Variance = 0.9837
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = 0.0409 (close to 0.0?)
#                                    variance = 0.8344 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.19914045666188163
# len 10000
# drill_loc  [1147. 6659. 2215.  166. 6136. 4674. 9688. 2216.  427.  218. 7510. 6777.
#  2595. 8999. 1390. 5316. 7160. 8631. 9357. 7389. 9967. 4070. 7365. 8513.
#    24. 1166. 1326. 7494.  596.  216. 1908. 3131.  626. 4662. 7548. 8013.
#  3062. 9460.  195.  863. 8700. 2733. 1352. 4359. 1981. 3587. 3701. 9692.
#  2789. 6063.]
# # wells  150
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1566
#                  Weighted Variance             = 0.0008
#                  Weighted Transformed Average  = 0.0326
#                  Weighted Transformed Variance = 0.9837
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = -0.0006 (close to 0.0?)
#                                    variance = 0.8467 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.172029682
# len 10000
# drill_loc  [1147. 6659. 2215.  166. 6136. 4674. 9688. 2216.  427.  218. 7510. 6777.
#  2595. 8999. 1390. 5316. 7160. 8631. 9357. 7389. 9967. 4070. 7365. 8513.
#    24. 1166. 1326. 7494.  596.  216. 1908. 3131.  626. 4662. 7548. 8013.
#  3062. 9460.  195.  863. 8700. 2733. 1352. 4359. 1981. 3587. 3701. 9692.
#  2789. 6063.]
# # wells  200
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1566
#                  Weighted Variance             = 0.0008
#                  Weighted Transformed Average  = 0.0326
#                  Weighted Transformed Variance = 0.9837
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = -0.0251 (close to 0.0?)
#                                    variance = 0.8638 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.10638033489321129
# len 10000
# drill_loc  [1147. 6659. 2215.  166. 6136. 4674. 9688. 2216.  427.  218. 7510. 6777.
#  2595. 8999. 1390. 5316. 7160. 8631. 9357. 7389. 9967. 4070. 7365. 8513.
#    24. 1166. 1326. 7494.  596.  216. 1908. 3131.  626. 4662. 7548. 8013.
#  3062. 9460.  195.  863. 8700. 2733. 1352. 4359. 1981. 3587. 3701. 9692.
#  2789. 6063.]
# # wells  250
# bins  100
# Text(0.5, 1.0, 'Journelian Bootstrap')

# %% [markdown]
# Lets get some summary statistics on our realizations.

# %%
JournelRealsDF = pd.DataFrame(mean_por, columns = ['Journelian Mean Porosity'])
JournelRealsDF.describe()
# Out:
#        Journelian Mean Porosity
# count                100.000000
# mean                   0.155445
# std                    0.004189
# min                    0.146684
# 25%                    0.152705
# 50%                    0.154880
# 75%                    0.158546
# max                    0.167911

# %% [markdown]
# This distribution can serve as our basis for comparing a similar method but with a imposed drilling strategy

# %% [markdown]
# ### Method 2: Journellian Bootstrap with Imposed Strategy - Isotropic

# %% [markdown]
# To apply our drilling strategy to our isotropic SGSIM models, we simply impelment our decision criteria into the sampling process from before.
#
# Lets first decide on 'sufficiently high' and 'sufficiently low' porosity values by looking at our original summary statistics.

# %%
df_iso.describe()
# Out:
#          porosity             X             Y
# count  100.000000    100.000000    100.000000
# mean     0.156600   5000.000000   5005.000000
# std      0.028230   3207.501495   3204.293994
# min      0.099888      0.000000     10.000000
# 25%      0.135223   2222.222222   2230.000000
# 50%      0.157307   5000.000000   5005.000000
# 75%      0.176815   7777.777778   7780.000000
# max      0.208837  10000.000000  10000.000000

# %%
threshold_por = np.percentile(df_iso['porosity'],75)
print(threshold_por)
# Out:
# 0.17681457125000002

# %% [markdown]
# We choose any porosity sampled below the P75 to be sufficiently low and a 'bad well' and any porosity sampled above the P75 to be sufficiently high and a 'good well'.
#
# ### Implement Strategy
#
# Now lets implement our strategy into our sampling process using loops. Before we implement this into our journellian method, lets demonstrate the process on a single SGSIM model.
#
# Our strategy loop will be worked into the sampling loop before we perform bootstrap so that we have our 'filtered' porosity distribution.
#
# We first need to develope a method to selectively sample from our defined annular region.

# %% [markdown]
# ### Build Annular Region
# Recall the Equation of a circle.

# %%
print('source: https://youtu.be/JvDpYlyKkNU')
Image("Equation of a Circle.PNG")
# Out:
# source: https://youtu.be/JvDpYlyKkNU

# %% [markdown]
# The output of our SGSIM model is an array of porosity values overlayed on X-Y coordinate arrays that we can use to define our annular regions with circles.
#
# Once the anular region is defined, we can take the corresponding porosity values for those selected X-Y coordinates as the boundaries of the circles.

# %%
df_iso
# Out:
#     porosity             X        Y
# 0   0.174974      0.000000     10.0
# 1   0.179391   1111.111111     10.0
# 2   0.148473   2222.222222     10.0
# 3   0.113139   3333.333333     10.0
# 4   0.167613   4444.444444     10.0
# ..       ...           ...      ...
# 95  0.135223   5555.555556  10000.0
# 96  0.201475   6666.666667  10000.0
# 97  0.157307   7777.777778  10000.0
# 98  0.104305   8888.888889  10000.0
# 99  0.183808  10000.000000  10000.0
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Interactive Imposed Strategy Sampling - Isotropic
#
# This block allows the user to scroll thorugh sampling iterations and see the strategy-imposed decisions in effect.
# - Keep in mind that the annular region defined for this example is not meaningful for an isotropic variogram where R1 = R2 and the 'annular' region would be any point inside R1 = R2, which is a circular region.
# The main focus is so showcase the sampling procedure, so an arbitray R2 (hmin variogram range) is chosen as a fraction of R1.

# %%
wellcount = 50
iteration = widgets.FloatSlider(min=1.0, max = 50.0, value = 0.01, step = 1.0, 
                            description = 'iteration',orientation='horizontal',
                            layout=Layout(width='500px', height='10px'))
iteration.style.handle_color = 'gray'
l = widgets.Text(value='                                     Interactive Strategy Visualization',
                 layout=Layout(width='500px', height='50px'))
ui1 = widgets.HBox([iteration],) # basic widget formatting    
ui = widgets.VBox([l,ui1],)

sample_array = sim_sk.flatten()
nx = 100; ny = 100; xsiz = 100.0; ysiz = 100.0
xmin = 0.0; xmax = 10000.0; ymin = 0.0; ymax = 10000.0

x = np.linspace(xmin,xmax,nx)
y = np.linspace(ymax,ymin,ny)
X,Y = np.meshgrid(x,y)
px = X.flatten()
py = Y.flatten()

goodwells = np.array([])                            #arrays of filterd samples from our SGSIM model using strategy
badwells = np.array([])
index = np.random.randint(0,len(sample_array))     #want to start with a random location from SGSIM model

wellx = np.array([])                              #arrays to store cordinates for the widget plot
welly = np.array([])
R1x = []
R1y = []
R2x = []
R2y = []

well_x = px[index]                                 #initial well location
well_y = py[index]
well_por = sample_array[index]


for i in range(0,wellcount):                              #want to drill 50 wells

    #define R1, R2 from major and minor axes, (here welll assume R2 is a fraction of R1 for demonstration
    #since they are equal when Isotropic)
    Hmaj = 1000
    Hmin = Hmaj/3
    R1 = np.array([])
    for i in range(len(px)):
        R1 = np.append(R1,np.sqrt((px[i]-well_x)**2 + (py[i]-well_y)**2))

    annulus = np.where((R1 <= Hmaj)&(R1 > Hmin))[0]        #regions of good and bad wells
    outsideR1 = np.where(R1 > Hmaj)[0]
    
    r1 = np.where(((R1 > Hmaj-50))&(R1<(Hmaj+50)))[0]        #Radii for plotting
    r2 = np.where(((R1 > Hmin-50))&(R1<(Hmin+50)))[0]
    
    annulusx = np.array([])                                #good well arrays
    annulusy = np.array([])
    annuluspor = np.array([])
        
    out_annulusx = np.array([])                            #bad well arrays
    out_annulusy = np.array([])
    out_annuluspor = np.array([])                              

    r1x = []                                               #lists for interactive plot; store radii cordinates 
    r1y = []
    r2x = []
    r2y = []

    for i in r1:
        r1x.append(px[i])
        r1y.append(py[i])
    for i in r2:
        r2x.append(px[i])
        r2y.append(py[i])

    for i in annulus:                                     #gathers x,y locations & porosities inside and outside annulus
        annulusx = np.append(annulusx,px[i])
        annulusy = np.append(annulusy,py[i])
        annuluspor = np.append(annuluspor,sample_array[i])
    for i in outsideR1:
        out_annulusx = np.append(out_annulusx,px[i])
        out_annulusy = np.append(out_annulusy,py[i])
        out_annuluspor = np.append(out_annuluspor,sample_array[i])

    if well_por >= threshold_por:                      #if a good well, sample stored for bootstrap, look inside annulus
        
        goodwells = np.append(goodwells,well_por)

        index = np.random.randint(0,len(annuluspor))
        well_x = annulusx[index]
        well_y = annulusy[index]
        well_por = annuluspor[index]
        
    elif well_por < threshold_por:                 #if a bad well, sample not stored for bootstrap , look outside annulus
        
        
        badwells = np.append(badwells,well_por)
        
        index = np.random.randint(0,len(out_annuluspor))
        well_x = out_annulusx[index]
        well_y = out_annulusy[index]
        well_por = out_annuluspor[index]
        

    wellx = np.append(wellx,well_x)
    welly = np.append(welly,well_y)
    R1x.append(r1x)
    R1y.append(r1y)
    R2x.append(r2x)
    R2y.append(r2y)

    

def search(iteration):
    
        
    sample_array = sim_sk.flatten()
    nx = 100; ny = 100; xsiz = 100.0; ysiz = 100.0
    xmin = 0.0; xmax = 10000.0; ymin = 0.0; ymax = 10000.0

    x = np.linspace(xmin,xmax,nx)
    y = np.linspace(ymax,ymin,ny)
    X,Y = np.meshgrid(x,y)
    px = X.flatten()
    py = Y.flatten()

    points = np.column_stack((px,py))
    values = sim_sk.flatten()
    Z = griddata(points,values,(X,Y),method = 'cubic') 
    levels = np.linspace(0.0,0.3,100)

    ax = plt.subplot(111)
    ax.contourf(X,Y,Z, cmap = 'inferno',levels = levels)
    C = ax.contourf(X,Y,Z, cmap = 'inferno',levels = levels)
    #cbar = fig.colorbar(C)
    cbar = plt.colorbar(C)
    cbar.set_label('Porosity')
    ax.set_xlabel('x (m)')
    ax.set_ylabel('y (m)')
    ax.set_title('SGSIM model')
    
    
    ax.plot(wellx[0:int(iteration)],welly[0:int(iteration)],'co')
    ax.plot(list(it.chain(*(R1x[0:int(iteration)]))),list(it.chain(*(R1y[0:int(iteration)]))),'w.')
    ax.plot(list(it.chain(*(R2x[0:int(iteration)]))),list(it.chain(*(R2y[0:int(iteration)]))),'w.')

    plt.subplots_adjust(left=0.0, bottom=0.0, right=1.4, top=1.4, wspace=0.5, hspace=0.5)

    plt.show()
    return
    
#Link the function to our widgets    
interactive_plot = widgets.interactive_output(search, {'iteration':iteration})
interactive_plot.clear_output(wait = True)               # delaying plot updating to reduce flikering

display(ui, interactive_plot)                           # display the interactive plot

print('# of good wells ', len(goodwells))
print(goodwells)

bins = 2
ax2 = plt.subplot(211)


bars = {'Good Well':len(goodwells),'Bad Well':len(badwells)}
names = list(bars.keys())
values = list(bars.values())

ax2.bar(names,values, width = 0.25,align = 'center',color = ['blue','red'])
ax2.set_title('Good Wells & Bad Wells')
ax2.set_ylabel('Count')
plt.ylim(0,50)


#Bootstrap Loop
mean_por = np.array([])
n = 0
while n < 100:                                     #n realizations (number of times we drill 50 wells)
    n+=1
    samples = np.array([])
    for i in range(0,len(goodwells)):
        index = np.random.randint(0,len(goodwells))
        samples = np.append(samples,goodwells[index])  #builds 1 full realization of 50 wells
    mean = np.mean(samples)
    mean_por = np.append(mean_por,mean)
    

#Visualize uncertainty distribution in single SGSIM model:

bins = 30
ax3 = plt.subplot(212)
n, bins,patches = plt.hist(mean_por,bins,facecolor = 'r',density=True)
plt.xlabel('Mean Porosity' )
plt.ylabel('Count')
plt.title('Uncertainty in Mean Porosity of well locations')

plt.subplots_adjust(left=0.0, bottom=0.0, right=1.2, top=2.2, wspace=0.1, hspace=0.1)
# Out:
# VBox(children=(Text(value='                                     Interactive Strategy Visualization', layout=La…
# Output()
# # of good wells  8
# [0.18834898 0.2061498  0.19558606 0.18966759 0.17791878 0.1823356
#  0.19558606 0.1823356 ]

# %% [markdown]
# We see that the number of acceptable wells samples is significanlty lower than the 50 wells we planned to drill.

# %% [markdown]
# ## Journelian Bootstrap with Imposed Strategy - Isotropic
#
# Now lets implement this strategy into our journellian Bootstrap approach.
# - The differnece from the above example is that once we have filtered good wells from bad wells, we simply repeat the process with a new SGSIM model and implement the same strategy. Once all of the good wells are gathered from all SGSIM realizations with applied strategy, we bootstrap these values and we will compare this to our standard Journellian approach from before.

# %%
SGSIMreals = 0   #of SGSIM Models for a distribution
ndata = 50
sample_array = sim_sk.flatten()
nx = 100; ny = 100; xsiz = 100.0; ysiz = 100.0
xmin = 0.0; xmax = 10000.0; ymin = 0.0; ymax = 10000.0

x = np.linspace(xmin,xmax,nx)
y = np.linspace(ymax,ymin,ny)
X,Y = np.meshgrid(x,y)
px = X.flatten()
py = Y.flatten()
goodwells_strat = np.array([])                            #arrays of filterd samples from our SGSIM model using strategy
badwells = np.array([])
seeds = 0 
 
for i in range(0,50):                                   
    index = int(np.random.randint(0,len(sample_array))) #pull from entire 10,000 data points of SGSIM model
well_x = px[index]
well_y = py[index]
while SGSIMreals < 5:           #number of isotropic SGSIM models for global distribution
    SGSIMreals += 1
    
    nx = 100; ny = 100; xsiz = 100.0; ysiz = 100.0; xmn = 5.0; ymn = 5.0; nxdis = 1; nydis = 1
    ndmin = 0; ndmax = 10; radius = 400; skmean = 0
    vario = GSLIB.make_variogram(nug=0.0,nst=1,it1=1,cc1=1.0,azi1=45.0,hmaj1=1000,hmin1=1000)
    tmin = -999; tmax = 999

#SGSIM model
    seeds += 1
    sim_sk = geostats.sgsim(df_iso,'X','Y','porosity',wcol=-1,scol=-1,tmin=tmin,tmax=tmax,itrans=1,ismooth=0,dftrans=0,tcol=0,
                twtcol=0,zmin=0.0,zmax=0.3,ltail=1,ltpar=0.0,utail=1,utpar=0.3,nsim=1,
                nx=nx,xmn=xmn,xsiz=xsiz,ny=ny,ymn=ymn,ysiz=ysiz,seed=seeds,
                ndmin=ndmin,ndmax=ndmax,nodmax=10,mults=0,nmult=2,noct=-1,radius=radius,radius1=1,sang1=0,
                mxctx=10,mxcty=10,ktype=0,colocorr=0.0,sec_map=0,vario=vario)

    
    sample_array = sim_sk.flatten()
    sampy = sample_array[50]
    print('sampy: ', str(sampy))
#-----------------------------------------------------------------------Setup Annular Region    
    nx = 100; ny = 100; xsiz = 100.0; ysiz = 100.0
    xmin = 0.0; xmax = 10000.0; ymin = 0.0; ymax = 10000.0

    x = np.linspace(xmin,xmax,nx)
    y = np.linspace(ymax,ymin,ny)
    X,Y = np.meshgrid(x,y)
    px = X.flatten()
    py = Y.flatten()

    
    index = np.random.randint(0,len(sample_array))     #want to start with a random location from SGSIM model
                              
    well_por = sample_array[index]                    #initial well location

#-----------------------------------------------------------------------Store Good Wells
    print('Applying Strategy for SGSIM model #'+ str(SGSIMreals))
    for i in range(0,wellcount):                              #want to drill 50 wells

        #define R1, R2 from major and minor axes, (here well assume R2 is a fraction of R1 for demonstration
        #since they are equal when Isotropic)
        Hmaj = 1000
        Hmin = Hmaj/3
        R1 = np.array([])
        for i in range(len(px)):
            R1 = np.append(R1,np.sqrt((px[i]-well_x)**2 + (py[i]-well_y)**2))

        annulus = np.where((R1 <= Hmaj)&(R1 > Hmin))[0]        #regions of good and bad wells
        outsideR1 = np.where(R1 > Hmaj)[0]

        r1 = np.where(((R1 > Hmaj-50))&(R1<(Hmaj+50)))[0]      #Radii for plotting
        r2 = np.where(((R1 > Hmin-50))&(R1<(Hmin+50)))[0]

        annulusx = np.array([])                                #good well arrays
        annulusy = np.array([])
        annuluspor = np.array([])

        out_annulusx = np.array([])                            #bad well arrays
        out_annulusy = np.array([])
        out_annuluspor = np.array([])                              

        for i in annulus:                                     #gathers x,y locations & porosities inside and outside annulus
            annulusx = np.append(annulusx,px[i])
            annulusy = np.append(annulusy,py[i])
            annuluspor = np.append(annuluspor,sample_array[i])
        for i in outsideR1:
            out_annulusx = np.append(out_annulusx,px[i])
            out_annulusy = np.append(out_annulusy,py[i])
            out_annuluspor = np.append(out_annuluspor,sample_array[i])
            
        if well_por >= threshold_por:                      #if a good well, sample stored for bootstrap, look inside annulus
            goodwells_strat = np.append(goodwells_strat,well_por)

            index = np.random.randint(0,len(annuluspor))
            well_x = annulusx[index]
            well_y = annulusy[index]
            well_por = annuluspor[index]
        
        elif well_por < threshold_por:                 #if a bad well, sample not stored for bootstrap , look outside annulus
            badwells = np.append(badwells,well_por)

            index = np.random.randint(0,len(out_annuluspor))
            well_x = out_annulusx[index]
            well_y = out_annulusy[index]
            well_por = out_annuluspor[index]

    print('Number of good wells so far: '+str(len(goodwells_strat)))
    print(goodwells_strat)
        
# by now we have our global distribution of 'good' wells drilled strategically accross multiple SGSIM models  

#-------------------------------------------------------------Bootstrap
mean_por_strat = np.array([])
n = 0
while n < 100:                                     #n realizations (number of times we drill 50 wells)
    n+=1
    samples = np.array([])
    for i in range(0,len(goodwells_strat)):
        index = np.random.randint(0,len(goodwells_strat))
        samples = np.append(samples,goodwells_strat[index])  #builds 1 full realization of 50 wells
    mean = np.mean(samples)
    mean_por_strat = np.append(mean_por_strat,mean)
    

#Visualize uncertainty distribution in single SGSIM model:

bins = 30
ax3 = plt.subplot(111)
n, bins,patches = plt.hist(mean_por_strat,bins,facecolor = 'r',density=True)
plt.xlabel('Mean Porosity' )
plt.ylabel('Count')
plt.title('Uncertainty in Mean Porosity of well locations')

#plt.subplots_adjust(left=0.0, bottom=0.0, right=1.2, top=2.2, wspace=0.1, hspace=0.1)
# Out:
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1566
#                  Weighted Variance             = 0.0008
#                  Weighted Transformed Average  = 0.0326
#                  Weighted Transformed Variance = 0.9837
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = 0.0096 (close to 0.0?)
#                                    variance = 0.8576 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.20883652100000002
# Applying Strategy for SGSIM model #1
# Number of good wells so far: 15
# [0.18080947 0.17716485 0.18512744 0.17711905 0.18966002 0.17791878
#  0.19224532 0.2044197  0.17929707 0.19569051 0.2044197  0.17993633
#  0.17939105 0.1823356  0.18036429]
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1566
#                  Weighted Variance             = 0.0008
#                  Weighted Transformed Average  = 0.0326
#                  Weighted Transformed Variance = 0.9837
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = 0.0329 (close to 0.0?)
#                                    variance = 0.8196 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.16235571915504562
# Applying Strategy for SGSIM model #2
# Number of good wells so far: 30
# [0.18080947 0.17716485 0.18512744 0.17711905 0.18966002 0.17791878
#  0.19224532 0.2044197  0.17929707 0.19569051 0.2044197  0.17993633
#  0.17939105 0.1823356  0.18036429 0.18040743 0.20307829 0.20712015
#  0.18799627 0.18243562 0.18969696 0.18815399 0.25913177 0.18567129
#  0.18736145 0.17939105 0.19558606 0.18380787 0.18432745 0.17939105]
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1566
#                  Weighted Variance             = 0.0008
#                  Weighted Transformed Average  = 0.0326
#                  Weighted Transformed Variance = 0.9837
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = 0.0409 (close to 0.0?)
#                                    variance = 0.8344 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.19914045666188163
# Applying Strategy for SGSIM model #3
# Number of good wells so far: 41
# [0.18080947 0.17716485 0.18512744 0.17711905 0.18966002 0.17791878
#  0.19224532 0.2044197  0.17929707 0.19569051 0.2044197  0.17993633
#  0.17939105 0.1823356  0.18036429 0.18040743 0.20307829 0.20712015
#  0.18799627 0.18243562 0.18969696 0.18815399 0.25913177 0.18567129
#  0.18736145 0.17939105 0.19558606 0.18380787 0.18432745 0.17939105
#  0.17791878 0.17939105 0.18843998 0.2044197  0.20162945 0.1823356
#  0.1823356  0.1823356  0.17939105 0.1823356  0.19853061]
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1566
#                  Weighted Variance             = 0.0008
#                  Weighted Transformed Average  = 0.0326
#                  Weighted Transformed Variance = 0.9837
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = -0.0006 (close to 0.0?)
#                                    variance = 0.8467 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.172029682
# Applying Strategy for SGSIM model #4
# Number of good wells so far: 54
# [0.18080947 0.17716485 0.18512744 0.17711905 0.18966002 0.17791878
#  0.19224532 0.2044197  0.17929707 0.19569051 0.2044197  0.17993633
#  0.17939105 0.1823356  0.18036429 0.18040743 0.20307829 0.20712015
#  0.18799627 0.18243562 0.18969696 0.18815399 0.25913177 0.18567129
#  0.18736145 0.17939105 0.19558606 0.18380787 0.18432745 0.17939105
#  0.17791878 0.17939105 0.18843998 0.2044197  0.20162945 0.1823356
#  0.1823356  0.1823356  0.17939105 0.1823356  0.19853061 0.17884414
#  0.17939105 0.20545443 0.1799761  0.19853061 0.19558606 0.19853061
#  0.20883652 0.19957904 0.1823356  0.19054069 0.2042177  0.18969696]
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1566
#                  Weighted Variance             = 0.0008
#                  Weighted Transformed Average  = 0.0326
#                  Weighted Transformed Variance = 0.9837
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = -0.0251 (close to 0.0?)
#                                    variance = 0.8638 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.10638033489321129
# Applying Strategy for SGSIM model #5
# Number of good wells so far: 65
# [0.18080947 0.17716485 0.18512744 0.17711905 0.18966002 0.17791878
#  0.19224532 0.2044197  0.17929707 0.19569051 0.2044197  0.17993633
#  0.17939105 0.1823356  0.18036429 0.18040743 0.20307829 0.20712015
#  0.18799627 0.18243562 0.18969696 0.18815399 0.25913177 0.18567129
#  0.18736145 0.17939105 0.19558606 0.18380787 0.18432745 0.17939105
#  0.17791878 0.17939105 0.18843998 0.2044197  0.20162945 0.1823356
#  0.1823356  0.1823356  0.17939105 0.1823356  0.19853061 0.17884414
#  0.17939105 0.20545443 0.1799761  0.19853061 0.19558606 0.19853061
#  0.20883652 0.19957904 0.1823356  0.19054069 0.2042177  0.18969696
#  0.19853061 0.19558606 0.17939105 0.20478002 0.20883652 0.18380787
#  0.18691869 0.17729524 0.17791878 0.20500797 0.18816248]
# Text(0.5, 1.0, 'Uncertainty in Mean Porosity of well locations')

# %% [markdown]
# ## Comparing Standard Journelian Bootstrap to Journelian Bootstrap with Imposed Strategy
#
# Both approaches created multiple unique SGSIM realizations to sample from and generated distributions for mean porosity, however to compare these 2 distributions accros 2 methods of sampling, we made sure to keep the unique SGSIM models the same across both methods for an 'apples to apples' comparison, ensuring that the sample space is shared and any differences in the distributions are due to the different sampling methods.
#
# Lets overlay the Uncertainty distributions of mean porosity using both sampling methods.

# %%
wells_df = pd.DataFrame(wells)
goodwells_df = pd.DataFrame(goodwells_strat)


bins1 = 30
bins1_ = 50
ax1 = plt.subplot(2,1,1)
n, bins,patches = ax1.hist(wells,bins1_,facecolor = 'r',density=True,
                           label = 'Constant Drill Locations Porosity Samples')
n, bins,patches = ax1.hist(goodwells_strat,bins1,facecolor = 'blue',density=True,alpha = .5,
                           label = 'Strategized Drill Locations Porosity Samples')

ax1.set_xlim([.1,.2])
ax1.set_xlabel('Good Wells Porosity' )
ax1.set_ylabel('Count')
ax1.set_title('Constant Drill Locations vs Strategized Drill Locations: Well Samples with Isotropic Variogram')
ax1.legend() 

print('No strategy Statistics: \n', wells_df.describe())
print('Strategy Statistics: \n', goodwells_df.describe())

bins2 = 30
ax2 = plt.subplot(2,1,2)
n, bins,patches = ax2.hist(mean_por_standard,bins2,facecolor = 'r',density=True,
                           label = 'Constant Drill Locations Mean Porosity')
n, bins,patches = ax2.hist(mean_por_strat,bins2,facecolor = 'blue',density=True,alpha = .5,
                           label = 'Strategized Drill Locations Mean Porosity')

ax2.set_xlim([.15,.2])
ax2.set_xlabel('Mean Porosity')
ax2.set_ylabel('Count')
ax2.set_title('Constant Drill Locations vs Strategized Drill Locations: Uncertainty in Mean Porosity with Isotropic Variogram')
ax2.legend() 


plt.subplots_adjust(left=0.0, bottom=0.0, right=1.2, top=2.2, wspace=0.1, hspace=0.3)
# Out:
# No strategy Statistics:
#                  0
# count  250.000000
# mean     0.155541
# std      0.025574
# min      0.095580
# 25%      0.137187
# 50%      0.157307
# 75%      0.176447
# max      0.208837
# Strategy Statistics:
#                 0
# count  65.000000
# mean    0.190097
# std     0.013187
# min     0.177119
# 25%     0.179976
# 50%     0.186919
# 75%     0.198531
# max     0.259132

# %% [markdown]
# We can clearly see the effect of imposed strategy on our uncertainty distributions between Journellian Bootstrap with constant drilling locations and Journellian Bootstrap with strategized drilling locations.
#
# There are many more samples in the former method as every well sample was included in the bootstrap process. It may be more insightful to compare our strategized method to a Journellian bootsrap method that does impose a threshold on porosity, but does not use our annular regions to determine the next sample. We shouldn't expect to see much of a difference between these two distributions becasue are our variogram is isotropic with samples far enough away from each other relative to the variogram range as to not condition each other when making an SGSIM model. This essentially means that our SGSIM model is random and we shouldn't expect the annular regions to make much of a difference by selecting a 'close' new drill location as opposed to drilling at the same locations across mutiple SGSIM models.
#
# Lets take the original code for our standard journelian method and apply a threshold.

# %%
SGSIMreals = 0   #of SGSIM Models for a distribution
ndata = 50
sample_array = sim_sk.flatten()

#take the SGSIM code(minus visualization) from above and work it into a loop for automation.

wells_threshold = np.array([]) 
drill_loc = np.array([])
seeds = 0
for i in range(0,50):                                   #drill 50 wells in the same location so we store this in 'drill_loc'
    index = int(np.random.randint(0,len(sample_array))) #pull from entire 10,000 data points of SGSIM model
    drill_loc = np.append(drill_loc,index)

while SGSIMreals < 5:           #number of isotropic SGSIM models for global distribution
    SGSIMreals += 1
    
    nx = 100; ny = 100; xsiz = 100.0; ysiz = 100.0; xmn = 5.0; ymn = 5.0; nxdis = 1; nydis = 1
    ndmin = 0; ndmax = 10; radius = 400; skmean = 0
    vario = GSLIB.make_variogram(nug=0.0,nst=1,it1=1,cc1=1.0,azi1=45.0,hmaj1=1000,hmin1=1000)
    tmin = -999; tmax = 999

#SGSIM model
    seeds += 1
    sim_sk = geostats.sgsim(df_iso,'X','Y','porosity',wcol=-1,scol=-1,tmin=tmin,tmax=tmax,itrans=1,ismooth=0,dftrans=0,tcol=0,
                twtcol=0,zmin=0.0,zmax=0.3,ltail=1,ltpar=0.0,utail=1,utpar=0.3,nsim=1,
                nx=nx,xmn=xmn,xsiz=xsiz,ny=ny,ymn=ymn,ysiz=ysiz,seed=seeds,
                ndmin=ndmin,ndmax=ndmax,nodmax=10,mults=0,nmult=2,noct=-1,radius=radius,radius1=1,sang1=0,
                mxctx=10,mxcty=10,ktype=0,colocorr=0.0,sec_map=0,vario=vario)

    
    sample_array = sim_sk.flatten()
    sampy = sample_array[50]
    print('sampy: ', sampy)
    print('len', len(sample_array))
    print('drill_loc ',drill_loc)

    
#----------------------------------------inserted threshold
    for i in range(0,len(drill_loc)):
        index1 = int(drill_loc[i])
        if sample_array[index1] >= threshold_por:          #if a good well, sample stored for bootstrap
            wells_threshold = np.append(wells_threshold,sample_array[index1])
    print('# wells ',len(wells_threshold))  
    print(wells_threshold)
#----------------------------------------
        
# by now we have our global distribution of wells drilled in multiple SGSIM models at the same locations 
# now perform bootstrap

mean_por_standard_threshold = np.array([])
n = 0
while n < 100:                                     #n realizations (number of times sample 250 wells)
    n+=1
    samples = np.array([])
    for i in range(0,len(wells_threshold)):
        index = np.random.randint(0,len(wells_threshold))
        samples = np.append(samples,wells_threshold[index])  #builds 1 full realization of all wells
    mean = np.mean(samples)
    mean_por_standard_threshold = np.append(mean_por_standard_threshold,mean)
    
print('bins ',len(mean_por_standard_threshold))
#Visualize
    
bins = 25
plt.subplot(1,1,1)
n, bins,patches = plt.hist(mean_por_standard_threshold,bins,facecolor = 'orange',density=True)
plt.xlabel('Mean Porosity')
plt.ylabel('Count')
plt.title('Journelian Bootstrap')
# Out:
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1566
#                  Weighted Variance             = 0.0008
#                  Weighted Transformed Average  = 0.0326
#                  Weighted Transformed Variance = 0.9837
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = 0.0096 (close to 0.0?)
#                                    variance = 0.8576 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.20883652100000002
# len 10000
# drill_loc  [9339. 4329. 5990.  242. 7103.  730. 6125. 6008. 8986. 7646. 2376. 1328.
#  4810. 6545. 6281.  579. 6016. 5353. 7215. 3566. 8976. 5180. 1111. 3329.
#  6376. 7874. 9605. 9166. 5242.  246. 6381. 5029. 4988. 2208. 5530. 7894.
#  6951. 2595. 3719. 7155.  201. 9388.  404. 7385. 5232. 7577. 6358. 6743.
#  2681. 9683.]
# # wells  15
# [0.19558606 0.18969696 0.1823356  0.1823356  0.18030684 0.1823356
#  0.18710613 0.188035   0.17934336 0.19502212 0.19532277 0.20883652
#  0.17785832 0.18380787 0.18274372]
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1566
#                  Weighted Variance             = 0.0008
#                  Weighted Transformed Average  = 0.0326
#                  Weighted Transformed Variance = 0.9837
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = 0.0329 (close to 0.0?)
#                                    variance = 0.8196 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.16235571915504562
# len 10000
# drill_loc  [9339. 4329. 5990.  242. 7103.  730. 6125. 6008. 8986. 7646. 2376. 1328.
#  4810. 6545. 6281.  579. 6016. 5353. 7215. 3566. 8976. 5180. 1111. 3329.
#  6376. 7874. 9605. 9166. 5242.  246. 6381. 5029. 4988. 2208. 5530. 7894.
#  6951. 2595. 3719. 7155.  201. 9388.  404. 7385. 5232. 7577. 6358. 6743.
#  2681. 9683.]
# # wells  30
# [0.19558606 0.18969696 0.1823356  0.1823356  0.18030684 0.1823356
#  0.18710613 0.188035   0.17934336 0.19502212 0.19532277 0.20883652
#  0.17785832 0.18380787 0.18274372 0.19853061 0.19853061 0.20035266
#  0.17791878 0.17690173 0.17939105 0.18380787 0.19558606 0.18627283
#  0.18380787 0.20721005 0.18327553 0.19201914 0.19310754 0.2044197 ]
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1566
#                  Weighted Variance             = 0.0008
#                  Weighted Transformed Average  = 0.0326
#                  Weighted Transformed Variance = 0.9837
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = 0.0409 (close to 0.0?)
#                                    variance = 0.8344 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.19914045666188163
# len 10000
# drill_loc  [9339. 4329. 5990.  242. 7103.  730. 6125. 6008. 8986. 7646. 2376. 1328.
#  4810. 6545. 6281.  579. 6016. 5353. 7215. 3566. 8976. 5180. 1111. 3329.
#  6376. 7874. 9605. 9166. 5242.  246. 6381. 5029. 4988. 2208. 5530. 7894.
#  6951. 2595. 3719. 7155.  201. 9388.  404. 7385. 5232. 7577. 6358. 6743.
#  2681. 9683.]
# # wells  42
# [0.19558606 0.18969696 0.1823356  0.1823356  0.18030684 0.1823356
#  0.18710613 0.188035   0.17934336 0.19502212 0.19532277 0.20883652
#  0.17785832 0.18380787 0.18274372 0.19853061 0.19853061 0.20035266
#  0.17791878 0.17690173 0.17939105 0.18380787 0.19558606 0.18627283
#  0.18380787 0.20721005 0.18327553 0.19201914 0.19310754 0.2044197
#  0.18969696 0.17939105 0.20883652 0.20837605 0.19853061 0.18586642
#  0.18575071 0.1823356  0.19620971 0.18224057 0.17939105 0.1823356 ]
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1566
#                  Weighted Variance             = 0.0008
#                  Weighted Transformed Average  = 0.0326
#                  Weighted Transformed Variance = 0.9837
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = -0.0006 (close to 0.0?)
#                                    variance = 0.8467 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.172029682
# len 10000
# drill_loc  [9339. 4329. 5990.  242. 7103.  730. 6125. 6008. 8986. 7646. 2376. 1328.
#  4810. 6545. 6281.  579. 6016. 5353. 7215. 3566. 8976. 5180. 1111. 3329.
#  6376. 7874. 9605. 9166. 5242.  246. 6381. 5029. 4988. 2208. 5530. 7894.
#  6951. 2595. 3719. 7155.  201. 9388.  404. 7385. 5232. 7577. 6358. 6743.
#  2681. 9683.]
# # wells  54
# [0.19558606 0.18969696 0.1823356  0.1823356  0.18030684 0.1823356
#  0.18710613 0.188035   0.17934336 0.19502212 0.19532277 0.20883652
#  0.17785832 0.18380787 0.18274372 0.19853061 0.19853061 0.20035266
#  0.17791878 0.17690173 0.17939105 0.18380787 0.19558606 0.18627283
#  0.18380787 0.20721005 0.18327553 0.19201914 0.19310754 0.2044197
#  0.18969696 0.17939105 0.20883652 0.20837605 0.19853061 0.18586642
#  0.18575071 0.1823356  0.19620971 0.18224057 0.17939105 0.1823356
#  0.1870245  0.18886636 0.17922048 0.2044197  0.1823356  0.17919901
#  0.20196307 0.19558606 0.20883652 0.17791878 0.1823356  0.1823356 ]
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1566
#                  Weighted Variance             = 0.0008
#                  Weighted Transformed Average  = 0.0326
#                  Weighted Transformed Variance = 0.9837
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = -0.0251 (close to 0.0?)
#                                    variance = 0.8638 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.10638033489321129
# len 10000
# drill_loc  [9339. 4329. 5990.  242. 7103.  730. 6125. 6008. 8986. 7646. 2376. 1328.
#  4810. 6545. 6281.  579. 6016. 5353. 7215. 3566. 8976. 5180. 1111. 3329.
#  6376. 7874. 9605. 9166. 5242.  246. 6381. 5029. 4988. 2208. 5530. 7894.
#  6951. 2595. 3719. 7155.  201. 9388.  404. 7385. 5232. 7577. 6358. 6743.
#  2681. 9683.]
# # wells  68
# [0.19558606 0.18969696 0.1823356  0.1823356  0.18030684 0.1823356
#  0.18710613 0.188035   0.17934336 0.19502212 0.19532277 0.20883652
#  0.17785832 0.18380787 0.18274372 0.19853061 0.19853061 0.20035266
#  0.17791878 0.17690173 0.17939105 0.18380787 0.19558606 0.18627283
#  0.18380787 0.20721005 0.18327553 0.19201914 0.19310754 0.2044197
#  0.18969696 0.17939105 0.20883652 0.20837605 0.19853061 0.18586642
#  0.18575071 0.1823356  0.19620971 0.18224057 0.17939105 0.1823356
#  0.1870245  0.18886636 0.17922048 0.2044197  0.1823356  0.17919901
#  0.20196307 0.19558606 0.20883652 0.17791878 0.1823356  0.1823356
#  0.20686481 0.19853061 0.18534898 0.20092371 0.20883652 0.17747308
#  0.17939105 0.17939105 0.17791878 0.19591798 0.17939105 0.1823356
#  0.19853061 0.17845487]
# bins  100
# Text(0.5, 1.0, 'Journelian Bootstrap')

# %% [markdown]
# Now lets compare our Constant Drilling Location Journellian Bootstrap with a threshold applied to our Jounrellian bootstrap with an imposed drilling strategy using an annular region.

# %%
#well samples from both methods 
wells_threshold_df = pd.DataFrame(wells_threshold)
goodwells_df = pd.DataFrame(goodwells_strat)


bins1 = 60

ax1 = plt.subplot(2,1,1)
n, bins,patches = ax1.hist(wells_threshold,bins1,facecolor = 'orange',density=True,
                           label = 'Constant Drill Locations Porosity Samples with Threshold ')
n, bins,patches = ax1.hist(goodwells_strat,bins1,facecolor = 'blue',density=True,alpha = .5,
                           label = 'Strategized Drill Locations Porosity Samples')

#ax1.set_xlim([.178,.2])
ax1.set_xlabel('Good Wells Porosity' )
ax1.set_ylabel('Count')
ax1.set_title('Constant Drill locations vs Strategized Drill Locations: Well Samples with Isotropic Variogram')
ax1.legend() 

print('Standard Statistics: \n', wells_threshold_df.describe())
print('Strategy Statistics: \n', goodwells_df.describe())

bins2 = 30
ax2 = plt.subplot(2,1,2)
n, bins,patches = ax2.hist(mean_por_standard_threshold,bins2,facecolor = 'orange',density=True,
                           label = 'Constant Drill Locations Mean Porosity with Threshold')
n, bins,patches = ax2.hist(mean_por_strat,bins2,facecolor = 'blue',density=True,alpha = .5,
                           label = 'Strategized Drill Locations Mean Porosity')

mean_por_standard_threshold_df = pd.DataFrame(mean_por_standard_threshold)
mean_por_strat_df  = pd.DataFrame(mean_por_strat)
print('Standard Statistics - Uncertainty in Mean Porosity: \n', mean_por_standard_threshold_df.describe())
print('Strategy Statistics - Uncertainty in Mean Porosity:: \n', mean_por_strat_df.describe())

#ax2.set_xlim([.185,.194])
ax2.set_xlabel('Mean Porosity')
ax2.set_ylabel('Count')
ax2.set_title('Constant Drill locations vs Strategized Drill Locations: Uncertainty in Mean Porosity with Isotropic Variogram')
ax2.legend() 


plt.subplots_adjust(left=0.0, bottom=0.0, right=1.2, top=2.2, wspace=0.1, hspace=0.3)
# Out:
# Standard Statistics:
#                 0
# count  68.000000
# mean    0.189266
# std     0.010032
# min     0.176902
# 25%     0.181757
# 50%     0.185809
# 75%     0.196790
# max     0.208837
# Strategy Statistics:
#                 0
# count  65.000000
# mean    0.190097
# std     0.013187
# min     0.177119
# 25%     0.179976
# 50%     0.186919
# 75%     0.198531
# max     0.259132
# Standard Statistics - Uncertainty in Mean Porosity:
#                  0
# count  100.000000
# mean     0.189239
# std      0.001214
# min      0.186920
# 25%      0.188372
# 50%      0.189228
# 75%      0.189943
# max      0.192076
# Strategy Statistics - Uncertainty in Mean Porosity::
#                  0
# count  100.000000
# mean     0.190145
# std      0.001440
# min      0.187052
# 25%      0.189246
# 50%      0.190220
# 75%      0.191028
# max      0.194092

# %% [markdown]
# ## Conclusion
# As we suspected, we dont see much of a difference between these two distributions because our SGSIM model for both methods is esentially random due to the spacing of our true well locations used to build the models. The annular regions dont effectively improve the samples based on spatial information for an isotropic variogram with data spaced outside of the variogram range.
#
# To see the full pontential of this imposed strategy we want to incorporate anisotropy in our SGSIM model, and to do this we should use more realistic data spacing for our SGSIM models.

# %% [markdown]
# # Anisotropy
# In the case our data is Anisotropic, we wont have an isotropic variogram and we will need determine the major and minor azimuths for our SGSIM model.
# For this we can calculate the variogram in all directions and visaully determine our major and minor azimuths.
# Lets first build a dataframe needed to use our working data.

# %%
df = pd.read_csv('sample_data_MV_biased-3.csv')
df.describe()
# Out:
#        Unnamed: 0           X           Y      Facies    Porosity  \
# count  368.000000  368.000000  368.000000  368.000000  368.000000
# mean   293.260870  499.565217  520.644022    0.597826    0.127026
# std    169.058258  289.770794  277.412187    0.491004    0.030642
# min      0.000000    0.000000    9.000000    0.000000    0.041122
# 25%    150.500000  240.000000  269.000000    0.000000    0.103412
# 50%    296.000000  500.000000  539.000000    1.000000    0.125842
# 75%    439.500000  762.500000  769.000000    1.000000    0.148623
# max    586.000000  990.000000  999.000000    1.000000    0.210258
#
#               Perm           AI
# count   368.000000   368.000000
# mean     85.617362  4791.736646
# std     228.362654   974.560569
# min       0.094627  1981.177309
# 25%       2.297348  4110.728374
# 50%      10.377292  4713.325533
# 75%      50.581288  5464.043562
# max    1991.097723  7561.250336

# %% [markdown]
# To fully appreciate the models we will build, lets reduce the number of true data points to 100

# %%
df = df.sample(100)


percentile = np.array(df['Porosity'])
Anisotropy_Threshold = np.percentile(percentile, 75)
df.describe()
# Out:
#        Unnamed: 0           X           Y     Facies    Porosity         Perm  \
# count  100.000000  100.000000  100.000000  100.00000  100.000000   100.000000
# mean   295.200000  520.500000  464.540000    0.57000    0.126445    91.362893
# std    166.603321  290.820417  288.325273    0.49757    0.031732   247.767056
# min      4.000000    0.000000   19.000000    0.00000    0.043853     0.094627
# 25%    151.250000  250.000000  176.500000    0.00000    0.102797     2.466762
# 50%    291.000000  520.000000  429.000000    1.00000    0.127080     7.807332
# 75%    427.250000  782.500000  721.500000    1.00000    0.146074    36.949927
# max    586.000000  970.000000  999.000000    1.00000    0.204587  1665.384124
#
#                 AI
# count   100.000000
# mean   4831.897617
# std     972.029457
# min    2534.551236
# 25%    4129.397372
# 50%    4659.470375
# 75%    5613.424843
# max    7132.799046

# %%
print('Anisotropy Porosity Threshold:', Anisotropy_Threshold)
# Out:
# Anisotropy Porosity Threshold: 0.14607446680602978

# %% [markdown]
# Lets visualize our spatial data

# %%
GSLIB.locmap_st(df,'X','Y','Porosity',0,1000,0,1000,.05,.3,'Porosity','X (m)','Y (m)','Porosity Map',plt.cm.plasma)
# Out:
# C:\Users\admin1\anaconda3\lib\site-packages\geostatspy\GSLIB.py:323: MatplotlibDeprecationWarning:
# The 'verts' parameter of scatter() was deprecated in Matplotlib 3.2 and will be removed two minor releases later. If any parameter follows 'verts', they should be passed as keyword, not positionally.
#   im = plt.scatter(

# %% [markdown]
# - From this map, we can get a sense of the minimum lag distance we want to use for our variogram. 50m seems reasonable given the proximity of data.
# - Now lets calculate the variogram of our truth model. We are going to determine the correct major and minor variogram azimuths by measuring the ranges of multiple variograms.

# %%
tmin = -9999.; tmax = 9999.                             # no trimming of our data 
lag_dist = 50.0; lag_tol = 50.0; nlag = 20;     # maximum lag is 1000m, log_tol > 1/2 lag distance (smoothing)
bandh = 9999.9; atol = 25                             # give bandwidth no effect: directional variograms
isill = 1                                               # standardize sill(equal to variance = 1 in normal trans)
azi_mat = [0,22.5,45,67.5,90,112.5,135,157.5]           # directions in azimuth to consider

#Store results in these arrays
lag = np.zeros((len(azi_mat),nlag+2))
variogram = np.zeros((len(azi_mat),nlag+2))
z = np.zeros((len(azi_mat),nlag+2))

for azi in range(0,len(azi_mat)):                      # Loop over all directions
    lag[azi,:], variogram[azi,:], z[azi,:] = geostats.gamv(df,"X","Y","Porosity",tmin,tmax,
                                                                lag_dist,lag_tol,nlag,azi_mat[azi],
                                                                atol,bandh,isill)
#visualize each variogram 
    plt.subplot(4,2,azi+1)
    plt.plot(lag[azi,:],variogram[azi,:],'o',color = 'r',label = 'Azimuth ' +str(azi_mat[azi]))
    plt.plot([0,2000],[1.0,1.0],color = 'black')
    plt.xlabel(r'Lag Distance $\bf(h)$, (m)')
    plt.ylabel(r'$\gamma \bf(h)$')
    plt.title('Directional NSCORE Porosity Variogram')
    plt.xlim([0,1000])
    plt.ylim([0,1.8])
    plt.legend(loc='upper left')
    plt.grid(True)

plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=4.2, wspace=0.2, hspace=0.3)
plt.show()

# %% [markdown]
# By exploring a range of directions, we have built a spatial continuity elipse of our data. We see that our major axis is 45 degrees (Range = 800m) and our minor axis is 135 degrees (Range = 300m). We will use these azimuths for our SGSIM model, so that the model is consistent with our data going foward.
#
# Lets build and visiualize the type of SGSIM model we will be using.

# %%
# we are setting our working variables that will be inputs to our sgsim fuction
nx = 100; ny = 100; xsiz = 10.0; ysiz = 10.0; xmn = 5.0; ymn = 5.0; nxdis = 1; nydis = 1
ndmin = 0; ndmax = 10; radius = 400; skmean = 0

#instatiation of a variogram model with necessary function parameters nugget effect, major & minor ranges, 
#azimuth, etc. 
vario = GSLIB.make_variogram(nug=0.0,nst=1,it1=1,cc1=1.0,azi1=45.0,hmaj1=800,hmin1=300)

#trimming limits (no effect on data)
tmin = -999; tmax = 999

#SGSIM model
sim_sk_aniso = geostats.sgsim(df,'X','Y','Porosity',wcol=-1,scol=-1,tmin=tmin,tmax=tmax,itrans=1,ismooth=0,dftrans=0,tcol=0,
            twtcol=0,zmin=0.0,zmax=0.3,ltail=1,ltpar=0.0,utail=1,utpar=0.3,nsim=1,
            nx=nx,xmn=xmn,xsiz=xsiz,ny=ny,ymn=ymn,ysiz=ysiz,seed=73073,
            ndmin=ndmin,ndmax=ndmax,nodmax=10,mults=0,nmult=2,noct=-1,radius=radius,radius1=1,sang1=0,
            mxctx=10,mxcty=10,ktype=0,colocorr=0.0,sec_map=0,vario=vario)

#visualize created SGSIM model
xmin = 0.0; xmax = 1000.0; ymin = 0.0; ymax = 1000.0; cmap = plt.cm.inferno
plt.subplot(111)  
GSLIB.locpix_st(sim_sk_aniso,xmin,xmax,ymin,ymax,xsiz,0.0,0.30,df,'X','Y','Porosity',
                'Sequential Gaussian Simulation - Simple Kriging','X(m)','Y(m)','Porosity',cmap)
plt.subplots_adjust(left=0.0, bottom=0.0, right=1.25, top=1.25, wspace=0.2, hspace=0.2)
print('simsk ', len(sim_sk))
# Out:
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1264
#                  Weighted Variance             = 0.001
#                  Weighted Transformed Average  = 0.0006
#                  Weighted Transformed Variance = 0.989
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = -0.1972 (close to 0.0?)
#                                    variance = 1.0202 (close to gammabar(V,V)? approx. 1.0)
# C:\Users\admin1\anaconda3\lib\site-packages\geostatspy\GSLIB.py:700: MatplotlibDeprecationWarning:
# The 'verts' parameter of scatter() was deprecated in Matplotlib 3.2 and will be removed two minor releases later. If any parameter follows 'verts', they should be passed as keyword, not positionally.
#   plt.scatter(
# simsk  100

# %% [markdown]
# ### Journellian Bootstrap: Constant Drilling Locations - with threshold - Anisotropic
#
# Lets create our distribution for uncertainty in mean porosity using constant drilling locations. We'll apply our threshold porosity as the P75 ouf our data like before

# %%
SGSIMreals = 0   #of SGSIM Models for a distribution
ndata = 50
sample_array = sim_sk_aniso.flatten()

#take the SGSIM code(minus visualization) from above and work it into a loop for automation.

wells_threshold_aniso = np.array([]) 
drill_loc = np.array([])
seeds = 0
for i in range(0,50):                                   #drill 50 wells in the same location so we store this in 'drill_loc'
    index = int(np.random.randint(0,len(sample_array))) #pull from entire 10,000 data points of SGSIM model
    drill_loc = np.append(drill_loc,index)

while SGSIMreals < 5:           #number of isotropic SGSIM models for global distribution
    SGSIMreals += 1
    
    nx = 100; ny = 100; xsiz = 10.0; ysiz = 10.0; xmn = 5.0; ymn = 5.0; nxdis = 1; nydis = 1
    ndmin = 0; ndmax = 10; radius = 400; skmean = 0
    vario = GSLIB.make_variogram(nug=0.0,nst=1,it1=1,cc1=1.0,azi1=45.0,hmaj1=800,hmin1=300)
    tmin = -999; tmax = 999

#SGSIM model
    seeds += 1
    sim_sk_aniso = geostats.sgsim(df,'X','Y','Porosity',wcol=-1,scol=-1,tmin=tmin,tmax=tmax,itrans=1,ismooth=0,dftrans=0,tcol=0,
                twtcol=0,zmin=0.0,zmax=0.3,ltail=1,ltpar=0.0,utail=1,utpar=0.3,nsim=1,
                nx=nx,xmn=xmn,xsiz=xsiz,ny=ny,ymn=ymn,ysiz=ysiz,seed=seeds,
                ndmin=ndmin,ndmax=ndmax,nodmax=10,mults=0,nmult=2,noct=-1,radius=radius,radius1=1,sang1=0,
                mxctx=10,mxcty=10,ktype=0,colocorr=0.0,sec_map=0,vario=vario)

    
    sample_array = sim_sk_aniso.flatten()
    sampy = sample_array[50]
    print('sampy: ', sampy)
    print('len', len(sample_array))
    print('drill_loc ',drill_loc)

    
#----------------------------------------inserted threshold
    for i in range(0,len(drill_loc)):
        index1 = int(drill_loc[i])
        if sample_array[index1] >= Anisotropy_Threshold:          #if a good well, sample stored for bootstrap
            wells_threshold_aniso = np.append(wells_threshold_aniso,sample_array[index1])
    print('# wells ',len(wells_threshold_aniso))  
    print(wells_threshold_aniso)
#----------------------------------------
        
# by now we have our global distribution of wells drilled in multiple SGSIM models at the same locations 
# now perform bootstrap

mean_por_standard_threshold_aniso = np.array([])
n = 0
while n < 100:                                     #n realizations (number of times sample 250 wells)
    n+=1
    samples = np.array([])
    for i in range(0,len(wells_threshold_aniso)):
        index = np.random.randint(0,len(wells_threshold_aniso))
        samples = np.append(samples,wells_threshold_aniso[index])  #builds 1 full realization of all wells
    mean = np.mean(samples)
    mean_por_standard_threshold_aniso = np.append(mean_por_standard_threshold_aniso,mean)
    
print('bins ',len(mean_por_standard_threshold_aniso))
#Visualize
    
bins = 25
plt.subplot(1,1,1)
n, bins,patches = plt.hist(mean_por_standard_threshold_aniso,bins,facecolor = 'red',density=True)
plt.xlabel('Mean Porosity')
plt.ylabel('Count')
plt.title('Journelian Bootstrap')
# Out:
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1264
#                  Weighted Variance             = 0.001
#                  Weighted Transformed Average  = 0.0006
#                  Weighted Transformed Variance = 0.989
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = -0.1906 (close to 0.0?)
#                                    variance = 0.9064 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.17136773428848837
# len 10000
# drill_loc  [4480. 6289. 7484. 6684.  819. 2564. 1380. 6060. 8293. 5256. 1728. 9832.
#  3555. 7878. 7508. 5019. 1528. 3552. 6019. 4751. 3680. 6031. 2366. 6936.
#  5364. 2938.  854. 5272.  907. 8917. 5968. 4631. 4563. 7410. 4569. 5328.
#  7893. 8670. 3290. 9936. 8531. 1220. 7510. 5617. 4726. 4653. 6996. 8044.
#  2423. 8877.]
# # wells  6
# [0.14608143 0.17216841 0.15700493 0.1982718  0.1857771  0.23702915]
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1264
#                  Weighted Variance             = 0.001
#                  Weighted Transformed Average  = 0.0006
#                  Weighted Transformed Variance = 0.989
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = -0.1622 (close to 0.0?)
#                                    variance = 0.9003 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.14403083376249967
# len 10000
# drill_loc  [4480. 6289. 7484. 6684.  819. 2564. 1380. 6060. 8293. 5256. 1728. 9832.
#  3555. 7878. 7508. 5019. 1528. 3552. 6019. 4751. 3680. 6031. 2366. 6936.
#  5364. 2938.  854. 5272.  907. 8917. 5968. 4631. 4563. 7410. 4569. 5328.
#  7893. 8670. 3290. 9936. 8531. 1220. 7510. 5617. 4726. 4653. 6996. 8044.
#  2423. 8877.]
# # wells  15
# [0.14608143 0.17216841 0.15700493 0.1982718  0.1857771  0.23702915
#  0.16510987 0.15437418 0.1544066  0.17675196 0.1675707  0.15130656
#  0.16138807 0.20415365 0.15451405]
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1264
#                  Weighted Variance             = 0.001
#                  Weighted Transformed Average  = 0.0006
#                  Weighted Transformed Variance = 0.989
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = -0.1779 (close to 0.0?)
#                                    variance = 0.9239 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.14996206522652747
# len 10000
# drill_loc  [4480. 6289. 7484. 6684.  819. 2564. 1380. 6060. 8293. 5256. 1728. 9832.
#  3555. 7878. 7508. 5019. 1528. 3552. 6019. 4751. 3680. 6031. 2366. 6936.
#  5364. 2938.  854. 5272.  907. 8917. 5968. 4631. 4563. 7410. 4569. 5328.
#  7893. 8670. 3290. 9936. 8531. 1220. 7510. 5617. 4726. 4653. 6996. 8044.
#  2423. 8877.]
# # wells  25
# [0.14608143 0.17216841 0.15700493 0.1982718  0.1857771  0.23702915
#  0.16510987 0.15437418 0.1544066  0.17675196 0.1675707  0.15130656
#  0.16138807 0.20415365 0.15451405 0.14914905 0.16985473 0.15312662
#  0.19980379 0.17966886 0.14608165 0.15659778 0.17216841 0.2042522
#  0.16961496]
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1264
#                  Weighted Variance             = 0.001
#                  Weighted Transformed Average  = 0.0006
#                  Weighted Transformed Variance = 0.989
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = -0.1867 (close to 0.0?)
#                                    variance = 0.8753 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.14591504532704722
# len 10000
# drill_loc  [4480. 6289. 7484. 6684.  819. 2564. 1380. 6060. 8293. 5256. 1728. 9832.
#  3555. 7878. 7508. 5019. 1528. 3552. 6019. 4751. 3680. 6031. 2366. 6936.
#  5364. 2938.  854. 5272.  907. 8917. 5968. 4631. 4563. 7410. 4569. 5328.
#  7893. 8670. 3290. 9936. 8531. 1220. 7510. 5617. 4726. 4653. 6996. 8044.
#  2423. 8877.]
# # wells  35
# [0.14608143 0.17216841 0.15700493 0.1982718  0.1857771  0.23702915
#  0.16510987 0.15437418 0.1544066  0.17675196 0.1675707  0.15130656
#  0.16138807 0.20415365 0.15451405 0.14914905 0.16985473 0.15312662
#  0.19980379 0.17966886 0.14608165 0.15659778 0.17216841 0.2042522
#  0.16961496 0.14854614 0.17216841 0.1530852  0.17190811 0.17216841
#  0.14928186 0.15432784 0.16237331 0.20439525 0.14735299]
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1264
#                  Weighted Variance             = 0.001
#                  Weighted Transformed Average  = 0.0006
#                  Weighted Transformed Variance = 0.989
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = -0.2198 (close to 0.0?)
#                                    variance = 0.8953 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.12033834727829126
# len 10000
# drill_loc  [4480. 6289. 7484. 6684.  819. 2564. 1380. 6060. 8293. 5256. 1728. 9832.
#  3555. 7878. 7508. 5019. 1528. 3552. 6019. 4751. 3680. 6031. 2366. 6936.
#  5364. 2938.  854. 5272.  907. 8917. 5968. 4631. 4563. 7410. 4569. 5328.
#  7893. 8670. 3290. 9936. 8531. 1220. 7510. 5617. 4726. 4653. 6996. 8044.
#  2423. 8877.]
# # wells  42
# [0.14608143 0.17216841 0.15700493 0.1982718  0.1857771  0.23702915
#  0.16510987 0.15437418 0.1544066  0.17675196 0.1675707  0.15130656
#  0.16138807 0.20415365 0.15451405 0.14914905 0.16985473 0.15312662
#  0.19980379 0.17966886 0.14608165 0.15659778 0.17216841 0.2042522
#  0.16961496 0.14854614 0.17216841 0.1530852  0.17190811 0.17216841
#  0.14928186 0.15432784 0.16237331 0.20439525 0.14735299 0.1714575
#  0.15173827 0.17316883 0.17216841 0.17216841 0.20413977 0.14903252]
# bins  100
# Text(0.5, 1.0, 'Journelian Bootstrap')

# %% [markdown]
# We will compare the results from this method to our imposed strategy method where we will use elipses from our varioram calcualtions to inform where inside our annular region we want our next 'good' sample to be, instead of randomly searching inside the annulus. This idea is presented below where the green regions would represent the target samples in the annulus and the red regions are samples we would want to avoid.

# %%
Image("ellipse_strategy.PNG",height =500,width = 500)

# %% [markdown]
# ### Defining Ellipses for Ansisotrpoic Annular Regions
#
# After getter a good well sample, we want to further restrain the subsequent sample to be selected within a window of the annular region that favors the major range of the variogram of the SGSIM model. This will give us more homogenous well samples and drive the well pattern along the high porosity streaks of our model. We would simply add this additional layer to our sample rejection filter.
#
# Lets show how we will be plotting the elliptical region as a selection filter.

# %%
sample_array_aniso = sim_sk_aniso.flatten()
nx = 100; ny = 100; xsiz = 10.0; ysiz = 10.0
xmin = 0.0; xmax = 1000.0; ymin = 0.0; ymax = 1000.0

x = np.linspace(xmin,xmax,nx)
y = np.linspace(ymax,ymin,ny)
X,Y = np.meshgrid(x,y)
px = X.flatten()
py = Y.flatten()

points = np.column_stack((px,py))
values = sim_sk_aniso.flatten()
Z = griddata(points,values,(X,Y),method = 'cubic') 
levels = np.linspace(0.0,0.3,100)
print(griddata)
ax = plt.subplot(111)
ax.contourf(X,Y,Z, cmap = 'inferno',levels = levels)
C = ax.contourf(X,Y,Z, cmap = 'inferno',levels = levels)
#cbar = fig.colorbar(C)
cbar = plt.colorbar(C)
cbar.set_label('Porosity')
ax.set_xlabel('x (m)')
ax.set_ylabel('y (m)')
ax.set_title('SGSIM model')
plt.subplots_adjust(left=0.0, bottom=0.0, right=1.25, top=1.25, wspace=0.2, hspace=0.2)

index = np.random.randint(0,len(sample_array))     #want to start with a random location from SGSIM model

wellx = np.array([])                              #arrays to store cordinates for the widget plot
welly = np.array([])
R1x = []
R1y = []
R2x = []
R2y = []
annulusx = np.array([])
annulusy = np.array([])

well_x = 500                                 #initial well location
well_y = 500
well_por = sample_array[index]


Hmaj = 200
Hmin = 50
x=500     #x-position of the center
y=500    #y-position of the center
a=600     #radius on the x-axis
b=75    #radius on the y-axis

t = np.linspace(0, 2*pi, 100)

R1 = np.array([])
Ra = np.array([])
for i in range(len(px)):
    R1 = np.append(R1,np.sqrt((px[i]-well_x)**2 + (py[i]-well_y)**2))
#----------------------------------------------------------------------------------------Ellipse Wings 
variogram_angle = 45
                                                                            #------------Ellipse
E =  Ellipse((well_x, well_y),width=Hmin*2.0,height=Hmaj*2.0,angle = 360-variogram_angle)
path_ellipse = E.get_path()
# Get the list of path vertices
vertices_ellipse = path_ellipse.vertices.copy()
# Transform the vertices so that they have the correct coordinates
vertices_ellipse = E.get_patch_transform().transform(vertices_ellipse)

p_ellipse = Path(vertices_ellipse) # make a polygon
path_boolean = p_ellipse.contains_points(points)
inside_ellipse = path_boolean == True
ex = px[inside_ellipse]
ey = py[inside_ellipse]

#outter boundary of ellipse(for plotting)
ellipse_x = []
ellipse_y = []
for i in range(len(vertices_ellipse)):
    ellipse_x.append(vertices_ellipse[i,0])
    ellipse_y.append(vertices_ellipse[i,1])
                                                                            #------------Circle
circle =  Circle((well_x, well_y), radius = Hmin)
path_circle = circle.get_path()
# Get the list of path vertices
vertices_circle = path_circle.vertices.copy()
# Transform the vertices so that they have the correct coordinates
vertices_circle = circle.get_patch_transform().transform(vertices_circle)

epoints = np.column_stack((ex,ey))

p_circle = Path(vertices_circle) # make a polygon
path_boolean_circle = p_circle.contains_points(epoints)    #important to define circle's points in terms of ellipse's points
inside_circle = path_boolean_circle == True
wings = path_boolean_circle == False

cx = ex[inside_circle]
cy = ey[inside_circle]

wingx = ex[wings]
wingy = ey[wings]
                                        #assigns corresponding porosity to annylar wings
wingspor = []
wpoints = np.column_stack((wingx,wingy))
wpoints = wpoints.tolist()
points = points.tolist()

for i in range(len(wpoints)):
    #print(wpoints[i])
    if wpoints[i] in points: 
        ind = points.index(wpoints[i])
        #print('p',points[ind])
        wingspor.append(sample_array_aniso[ind])

#-------------------------------------------------------------------------------------------------    
annulus = np.where((R1 <= Hmaj)&(R1 > Hmin))[0]        #regions of good and bad wells
outsideR1 = np.where(R1 > Hmaj)[0]

r1 = np.where(((R1 > Hmaj-5))&(R1<(Hmaj+5)))[0]        #Radii for plotting
r2 = np.where(((R1 > Hmin-5))&(R1<(Hmin+5)))[0]


r1x = []                                               #lists for interactive plot; store radii cordinates 
r1y = []
r2x = []
r2y = []


for i in r1:
    r1x.append(px[i])
    r1y.append(py[i])
for i in r2:
    r2x.append(px[i])
    r2y.append(py[i])
for i in annulus:                                     #gathers x,y locations & porosities inside and outside annulus
    annulusx = np.append(annulusx,px[i])
    annulusy = np.append(annulusy,py[i])
    annuluspor = np.append(annuluspor,sample_array[i])

    
    

ax.plot(r1x,r1y,'wx')
ax.plot(r2x,r2y,'wx')
ax.plot(ellipse_x,ellipse_y,'wx')
#ax.plot(ex,ey,'gx')
#ax.plot(cx,cy,'rx')
ax.plot(wingx,wingy,'gx')
# Out:
# <function griddata at 0x00000206DF625C10>

# %% [markdown]
# Lets visualize our imposed strategy by interactively samping drill locations and processing good samples through our elliptical region. Like before, this proces is demonstrated on a single SGSIM model for convenience.

# %%
wellcount = 50
iteration = widgets.FloatSlider(min=1.0, max = 50.0, value = 0.01, step = 1.0, 
                            description = 'iteration',orientation='horizontal',
                            layout=Layout(width='500px', height='10px'))
iteration.style.handle_color = 'gray'
l = widgets.Text(value='                                     Interactive Strategy Visualization',
                 layout=Layout(width='500px', height='50px'))
ui1 = widgets.HBox([iteration],) # basic widget formatting    
ui = widgets.VBox([l,ui1],)

sample_array_aniso = sim_sk_aniso.flatten()
nx = 100; ny = 100; xsiz = 10.0; ysiz = 10.0
xmin = 0.0; xmax = 1000.0; ymin = 0.0; ymax = 1000.0

x = np.linspace(xmin,xmax,nx)
y = np.linspace(ymax,ymin,ny)
X,Y = np.meshgrid(x,y)
px = X.flatten()
py = Y.flatten()



goodwells_aniso = np.array([])                            #arrays of filterd samples from our SGSIM model using strategy
badwells_aniso = np.array([])
index = np.random.randint(0,len(sample_array_aniso))     #want to start with a random location from SGSIM model

wellx = np.array([])                              #arrays to store cordinates for the widget plot
welly = np.array([])
R1x = []
R1y = []
R2x = []
R2y = []
Wx = []
Wy = []


well_x = px[index]                                 #initial random well location
well_y = py[index]
well_por = sample_array_aniso[index]


#-------------------------------------------------------------------------------------------------Sampling 

for i in range(0,wellcount):                              #want to drill 50 wells

    #define R1, R2 from major and minor axes
    Hmaj = 200
    Hmin = 50
    R1 = np.array([])
    for i in range(len(px)):
        R1 = np.append(R1,np.sqrt((px[i]-well_x)**2 + (py[i]-well_y)**2))

    annulus = np.where((R1 <= Hmaj)&(R1 > Hmin))[0]        #regions of good and bad wells
    outsideR1 = np.where(R1 > Hmaj)[0]
    
    r1 = np.where(((R1 > Hmaj-5))&(R1<(Hmaj+5)))[0]        #Radii for plotting
    r2 = np.where(((R1 > Hmin-5))&(R1<(Hmin+5)))[0]
    
    annulusx = np.array([])                                #good well arrays
    annulusy = np.array([])
    annuluspor = np.array([])
        
    out_annulusx = np.array([])                            #bad well arrays
    out_annulusy = np.array([])
    out_annuluspor = np.array([])                              

    r1x = []                                               #lists for interactive plot; store radii cordinates 
    r1y = []
    r2x = []
    r2y = []
    
    #----------------------------------------------------------------------------------------Ellipse Wings 
    variogram_angle = 45
                                                                                #------------Ellipse
    E =  Ellipse((well_x, well_y),width=Hmin*2.0,height=Hmaj*2.0,angle = 360-variogram_angle)
    path_ellipse = E.get_path()
    # Get the list of path vertices
    vertices_ellipse = path_ellipse.vertices.copy()
    # Transform the vertices so that they have the correct coordinates
    vertices_ellipse = E.get_patch_transform().transform(vertices_ellipse)

    p_ellipse = Path(vertices_ellipse) # make a polygon
    path_boolean = p_ellipse.contains_points(points)
    inside_ellipse = path_boolean == True
    ex = px[inside_ellipse]
    ey = py[inside_ellipse]

    #outter boundary of ellipse(for plotting)
    ellipse_x = []
    ellipse_y = []
    for i in range(len(vertices_ellipse)):
        ellipse_x.append(vertices_ellipse[i,0])
        ellipse_y.append(vertices_ellipse[i,1])
                                                                                #------------Circle
    circle =  Circle((well_x, well_y), radius = Hmin)
    path_circle = circle.get_path()
    # Get the list of path vertices
    vertices_circle = path_circle.vertices.copy()
    # Transform the vertices so that they have the correct coordinates
    vertices_circle = circle.get_patch_transform().transform(vertices_circle)

    epoints = np.column_stack((ex,ey))

    p_circle = Path(vertices_circle) # make a polygon
    path_boolean_circle = p_circle.contains_points(epoints)    #important to define circle's points in terms of ellipse's points
    inside_circle = path_boolean_circle == True
    wings = path_boolean_circle == False

    cx = ex[inside_circle]
    cy = ey[inside_circle]

    wingx = ex[wings]
    wingy = ey[wings]

                                            #assigns corresponding porosity to annylar wings
    wingspor = []
    wpoints = np.column_stack((wingx,wingy))
    wpoints = wpoints.tolist()
    #points = points.tolist()

    for i in range(len(wpoints)):
        #print(wpoints[i])
        if wpoints[i] in points: 
            ind = points.index(wpoints[i])
            #print('p',points[ind])
            wingspor.append(sample_array_aniso[ind])
    
    

#-------------------------------------------------------------------------------------------------

    for i in r1:
        r1x.append(px[i])
        r1y.append(py[i])
    for i in r2:
        r2x.append(px[i])
        r2y.append(py[i])                              #gathers x,y locations & porosities inside and outside annulus

    for i in outsideR1:
        out_annulusx = np.append(out_annulusx,px[i])
        out_annulusy = np.append(out_annulusy,py[i])
        out_annuluspor = np.append(out_annuluspor,sample_array[i])

    if well_por >= Anisotropy_Threshold:                      #if a good well, sample stored for bootstrap, look inside annulus
        
        goodwells_aniso = np.append(goodwells_aniso,well_por)

        index = np.random.randint(0,len(wingspor))
        well_x = wingx[index]
        well_y = wingy[index]
        well_por = wingspor[index]
        
    elif well_por < Anisotropy_Threshold:                 #if a bad well, sample not stored for bootstrap , look outside annulus
        
        
        badwells_aniso = np.append(badwells_aniso,well_por)
        
        index = np.random.randint(0,len(out_annuluspor))
        well_x = out_annulusx[index]
        well_y = out_annulusy[index]
        well_por = out_annuluspor[index]
        
        
                                                #these Rs are 2d lists of len(wellcount), each item stores x or y points
                                                #for R1 & R2 radii of a given well location. filled once per loop iteration
    wellx = np.append(wellx,well_x)
    welly = np.append(welly,well_y)
    R1x.append(r1x)
    R1y.append(r1y)
    R2x.append(r2x)
    R2y.append(r2y)
    Wx.append(wingx)
    Wy.append(wingy)


def search(iteration):
    
        
    sample_array = sim_sk_aniso.flatten()
    nx = 100; ny = 100; xsiz = 10.0; ysiz = 10.0
    xmin = 0.0; xmax = 1000.0; ymin = 0.0; ymax = 1000.0

    x = np.linspace(xmin,xmax,nx)
    y = np.linspace(ymax,ymin,ny)
    X,Y = np.meshgrid(x,y)
    px = X.flatten()
    py = Y.flatten()

    points = np.column_stack((px,py))
    values = sample_array.flatten()
    Z = griddata(points,values,(X,Y),method = 'cubic') 
    levels = np.linspace(0.0,0.3,100)

    ax = plt.subplot(111)
    ax.contourf(X,Y,Z, cmap = 'inferno',levels = levels)
    C = ax.contourf(X,Y,Z, cmap = 'inferno',levels = levels)
    #cbar = fig.colorbar(C)
    cbar = plt.colorbar(C)
    cbar.set_label('Porosity')
    ax.set_xlabel('x (m)')
    ax.set_ylabel('y (m)')
    ax.set_title('Anisotropic SGSIM model')
    
     
    ax.plot(wellx[0:int(iteration)],welly[0:int(iteration)],'co')
    ax.plot(list(it.chain(*(R1x[0:int(iteration)]))),list(it.chain(*(R1y[0:int(iteration)]))),'w.')
    ax.plot(list(it.chain(*(R2x[0:int(iteration)]))),list(it.chain(*(R2y[0:int(iteration)]))),'w.')
    ax.plot(list(it.chain(*(Wx[0:int(iteration)]))),list(it.chain(*(Wy[0:int(iteration)]))),'g.')


    plt.subplots_adjust(left=0.0, bottom=0.0, right=1.4, top=1.4, wspace=0.5, hspace=0.5)

    plt.show()
    return
    
#Link the function to our widgets    
interactive_plot = widgets.interactive_output(search, {'iteration':iteration})
interactive_plot.clear_output(wait = True)               # delaying plot updating to reduce flikering

display(ui, interactive_plot)                           # display the interactive plot

print('# of good wells ', len(goodwells_aniso))
print(goodwells_aniso)
print("bad", len(badwells_aniso))

bins = 2
ax2 = plt.subplot(211)


bars = {'Good Well':len(goodwells_aniso),'Bad Well':len(badwells_aniso)}
names = list(bars.keys())
values = list(bars.values())

ax2.bar(names,values, width = 0.25,align = 'center',color = ['blue','red'])
ax2.set_title('Good Wells & Bad Wells')
ax2.set_ylabel('Count')
plt.ylim(0,50)


#Bootstrap Loop
mean_por = np.array([])
n = 0
while n < 100:                                     #n realizations (number of times we drill 50 wells)
    n+=1
    samples = np.array([])
    for i in range(0,len(goodwells_aniso)):
        index = np.random.randint(0,len(goodwells_aniso))
        samples = np.append(samples,goodwells_aniso[index])  #builds 1 full realization of 50 wells
    mean = np.mean(samples)
    mean_por = np.append(mean_por,mean)
    

#Visualize uncertainty distribution in single SGSIM model:
if len(goodwells_aniso > 0):
    bins = 30
    ax3 = plt.subplot(212)
    n, bins,patches = plt.hist(mean_por,bins,facecolor = 'r',density=True)
    plt.xlabel('Mean Porosity' )
    plt.ylabel('Count')
    plt.title('Uncertainty in Mean Porosity of well locations')

    plt.subplots_adjust(left=0.0, bottom=0.0, right=1.2, top=2.2, wspace=0.1, hspace=0.1)
# Out:
# VBox(children=(Text(value='                                     Interactive Strategy Visualization', layout=La…
# Output()
# # of good wells  19
# [0.16950478 0.17191312 0.15529863 0.15696185 0.14877243 0.17655587
#  0.20412716 0.17044748 0.14836909 0.15549057 0.16906002 0.15666007
#  0.18088878 0.17047811 0.160544   0.15491891 0.17773192 0.15677355
#  0.15062854]
# bad 31

# %% [markdown]
# Notice how the smapling pattern follows streaks of good porosity. Once a good well sample is taken, it is highly likey that the subseqeunt sample will lie in the ellipse of that well and the pattern continues until a given streak is exhausted or a bad sample is taken. In both cases a new streak is found and traced. It should be interesting to compare the uncertainty in this ditribution to a constant drilling location strategy.
#
# Lets run the full sampling process by repeating the above process for multiple SGSIM models.

# %%
SGSIMreals = 0   #of SGSIM Models for a distribution
ndata = 50
sample_array_aniso = sim_sk_aniso.flatten()

goodwells_aniso = np.array([])                            #arrays of filterd samples from our SGSIM model using strategy
badwells_aniso = np.array([])
seeds = 0                       
for i in range(0,50):                                   
    index = int(np.random.randint(0,len(sample_array))) #pull from entire 10,000 data points of SGSIM model

well_x = px[index]
well_y = py[index]
while SGSIMreals < 5:           #number of isotropic SGSIM models for global distribution
    SGSIMreals += 1
    
    nx = 100; ny = 100; xsiz = 10.0; ysiz = 10.0; xmn = 5.0; ymn = 5.0; nxdis = 1; nydis = 1
    ndmin = 0; ndmax = 10; radius = 400; skmean = 0
    vario = GSLIB.make_variogram(nug=0.0,nst=1,it1=1,cc1=1.0,azi1=45.0,hmaj1=800,hmin1=300)
    tmin = -999; tmax = 999

#SGSIM model
    seeds += 1
    sim_sk_aniso = geostats.sgsim(df,'X','Y','Porosity',wcol=-1,scol=-1,tmin=tmin,tmax=tmax,itrans=1,ismooth=0,dftrans=0,tcol=0,
                twtcol=0,zmin=0.0,zmax=0.3,ltail=1,ltpar=0.0,utail=1,utpar=0.3,nsim=1,
                nx=nx,xmn=xmn,xsiz=xsiz,ny=ny,ymn=ymn,ysiz=ysiz,seed=seeds,
                ndmin=ndmin,ndmax=ndmax,nodmax=10,mults=0,nmult=2,noct=-1,radius=radius,radius1=1,sang1=0,
                mxctx=10,mxcty=10,ktype=0,colocorr=0.0,sec_map=0,vario=vario)

    
    sample_array = sim_sk_aniso.flatten()
    sampy = sample_array[50]
    print('sampy: ', str(sampy))
#-----------------------------------------------------------------------Setup Annular Region    
    nx = 100; ny = 100; xsiz = 10.0; ysiz = 10.0
    xmin = 0.0; xmax = 1000.0; ymin = 0.0; ymax = 1000.0

    x = np.linspace(xmin,xmax,nx)
    y = np.linspace(ymax,ymin,ny)
    X,Y = np.meshgrid(x,y)
    px = X.flatten()
    py = Y.flatten()

    
    index = np.random.randint(0,len(sample_array))     #want to start with a random location from SGSIM model
                              
    well_por = sample_array[index]                    #initial well location

#-----------------------------------------------------------------------Store Good Wells
    print('Applying Strategy for SGSIM model #'+ str(SGSIMreals))
    for i in range(0,wellcount):                              #want to drill 50 wells

        #define R1, R2 from major and minor axes
        Hmaj = 800
        Hmin = 300
        R1_aniso = np.array([])
        for i in range(len(px)):
            R1_aniso = np.append(R1_aniso,np.sqrt((px[i]-well_x)**2 + (py[i]-well_y)**2))

        annulus_aniso = np.where((R1_aniso <= Hmaj)&(R1_aniso > Hmin))[0]        #regions of good and bad wells
        outsideR1_aniso = np.where(R1_aniso > Hmaj)[0]

        r1 = np.where(((R1_aniso > Hmaj-50))&(R1_aniso<(Hmaj+50)))[0]      #Radii for plotting
        r2 = np.where(((R1_aniso > Hmin-50))&(R1_aniso<(Hmin+50)))[0]

        annulusx = np.array([])                                #good well arrays
        annulusy = np.array([])
        annuluspor = np.array([])

        out_annulusx = np.array([])                            #bad well arrays
        out_annulusy = np.array([])
        out_annuluspor = np.array([])
        
         #----------------------------------------------------------------------------------------Ellipse Wings 
        Hmaj = 800
        Hmin = 300
        variogram_angle = 45
                                                                                    #------------Ellipse
        E =  Ellipse((well_x, well_y),width=Hmin*2.0,height=Hmaj*2.0,angle = 360-variogram_angle)
        path_ellipse = E.get_path()
        # Get the list of path vertices
        vertices_ellipse = path_ellipse.vertices.copy()
        # Transform the vertices so that they have the correct coordinates
        vertices_ellipse = E.get_patch_transform().transform(vertices_ellipse)

        p_ellipse = Path(vertices_ellipse) # make a polygon
        path_boolean = p_ellipse.contains_points(points)
        inside_ellipse = path_boolean == True
        ex = px[inside_ellipse]
        ey = py[inside_ellipse]

        #outter boundary of ellipse(for plotting)
        ellipse_x = []
        ellipse_y = []
        for i in range(len(vertices_ellipse)):
            ellipse_x.append(vertices_ellipse[i,0])
            ellipse_y.append(vertices_ellipse[i,1])
                                                                                    #------------Circle
        circle =  Circle((well_x, well_y), radius = Hmin)
        path_circle = circle.get_path()
        # Get the list of path vertices
        vertices_circle = path_circle.vertices.copy()
        # Transform the vertices so that they have the correct coordinates
        vertices_circle = circle.get_patch_transform().transform(vertices_circle)

        epoints = np.column_stack((ex,ey))

        p_circle = Path(vertices_circle) # make a polygon
        path_boolean_circle = p_circle.contains_points(epoints)    #important to define circle's points in terms of ellipse's points
        inside_circle = path_boolean_circle == True
        wings = path_boolean_circle == False

        cx = ex[inside_circle]
        cy = ey[inside_circle]

        wingx = ex[wings]
        wingy = ey[wings]

                                                #assigns corresponding porosity to annylar wings
        wingspor = []
        wpoints = np.column_stack((wingx,wingy))
        wpoints = wpoints.tolist()

        for i in range(len(wpoints)):
            #print(wpoints[i])
            if wpoints[i] in points: 
                ind = points.index(wpoints[i])
                #print('p',points[ind])
                wingspor.append(sample_array_aniso[ind])


    #-------------------------------------------------------------------------------------------------

        for i in outsideR1:
            out_annulusx = np.append(out_annulusx,px[i])
            out_annulusy = np.append(out_annulusy,py[i])
            out_annuluspor = np.append(out_annuluspor,sample_array[i])
        if well_por >= Anisotropy_Threshold:         #if a good well, sample stored for bootstrap, look inside annulus

            goodwells_aniso = np.append(goodwells_aniso,well_por)

            index = np.random.randint(0,len(wingspor))
            well_x = wingx[index]
            well_y = wingy[index]
            well_por = wingspor[index]

        elif well_por < Anisotropy_Threshold:        #if a bad well, sample not stored for bootstrap , look outside annulus

            badwells_aniso = np.append(badwells_aniso,well_por)

            index = np.random.randint(0,len(out_annuluspor))
            well_x = out_annulusx[index]
            well_y = out_annulusy[index]
            well_por = out_annuluspor[index]

    print('Number of good wells so far: '+str(len(goodwells_aniso)))
    print(goodwells_aniso)

# by now we have our global distribution of 'good' wells drilled strategically accross multiple SGSIM models  

#-------------------------------------------------------------Bootstrap
mean_por_aniso = np.array([])
n = 0
while n < 100:                                     #n realizations (number of times we drill 50 wells)
    n+=1
    samples = np.array([])
    for i in range(0,len(goodwells_aniso)):
        index = np.random.randint(0,len(goodwells_aniso))
        samples = np.append(samples,goodwells_aniso[index])  #builds 1 full realization of 50 wells
    mean = np.mean(samples)
    mean_por_aniso = np.append(mean_por_aniso,mean)
    

#Visualize uncertainty distribution in single SGSIM model:

bins = 30
ax3 = plt.subplot(111)
n, bins,patches = plt.hist(mean_por_aniso,bins,facecolor = 'r',density=True)
plt.xlabel('Mean Porosity' )
plt.ylabel('Count')
plt.title('Uncertainty in Mean Porosity of well locations')

#plt.subplots_adjust(left=0.0, bottom=0.0, right=1.2, top=2.2, wspace=0.1, hspace=0.1)
# Out:
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1264
#                  Weighted Variance             = 0.001
#                  Weighted Transformed Average  = 0.0006
#                  Weighted Transformed Variance = 0.989
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = -0.1906 (close to 0.0?)
#                                    variance = 0.9064 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.17136773428848837
# Applying Strategy for SGSIM model #1
# Number of good wells so far: 13
# [0.15612876 0.18412938 0.14669515 0.14942234 0.15510452 0.15420596
#  0.15440298 0.17678703 0.20413875 0.14696983 0.15443593 0.18312661
#  0.15623126]
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1264
#                  Weighted Variance             = 0.001
#                  Weighted Transformed Average  = 0.0006
#                  Weighted Transformed Variance = 0.989
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = -0.1622 (close to 0.0?)
#                                    variance = 0.9003 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.14403083376249967
# Applying Strategy for SGSIM model #2
# Number of good wells so far: 23
# [0.15612876 0.18412938 0.14669515 0.14942234 0.15510452 0.15420596
#  0.15440298 0.17678703 0.20413875 0.14696983 0.15443593 0.18312661
#  0.15623126 0.14875672 0.15639977 0.15446086 0.15184634 0.17724552
#  0.16830748 0.15255321 0.15474004 0.1460789  0.14958946]
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1264
#                  Weighted Variance             = 0.001
#                  Weighted Transformed Average  = 0.0006
#                  Weighted Transformed Variance = 0.989
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = -0.1779 (close to 0.0?)
#                                    variance = 0.9239 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.14996206522652747
# Applying Strategy for SGSIM model #3
# Number of good wells so far: 34
# [0.15612876 0.18412938 0.14669515 0.14942234 0.15510452 0.15420596
#  0.15440298 0.17678703 0.20413875 0.14696983 0.15443593 0.18312661
#  0.15623126 0.14875672 0.15639977 0.15446086 0.15184634 0.17724552
#  0.16830748 0.15255321 0.15474004 0.1460789  0.14958946 0.15150831
#  0.1730967  0.15809201 0.18290151 0.1544018  0.14944018 0.18225688
#  0.16957248 0.16077699 0.15442452 0.17216841]
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1264
#                  Weighted Variance             = 0.001
#                  Weighted Transformed Average  = 0.0006
#                  Weighted Transformed Variance = 0.989
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = -0.1867 (close to 0.0?)
#                                    variance = 0.8753 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.14591504532704722
# Applying Strategy for SGSIM model #4
# Number of good wells so far: 42
# [0.15612876 0.18412938 0.14669515 0.14942234 0.15510452 0.15420596
#  0.15440298 0.17678703 0.20413875 0.14696983 0.15443593 0.18312661
#  0.15623126 0.14875672 0.15639977 0.15446086 0.15184634 0.17724552
#  0.16830748 0.15255321 0.15474004 0.1460789  0.14958946 0.15150831
#  0.1730967  0.15809201 0.18290151 0.1544018  0.14944018 0.18225688
#  0.16957248 0.16077699 0.15442452 0.17216841 0.15644068 0.15175644
#  0.14628316 0.15206708 0.19490354 0.17683581 0.17234634 0.17226562]
#
#  Data for SGSIM: Number of acceptable data     = 100
#                  Number trimmed                = 0
#                  Weighted Average              = 0.1264
#                  Weighted Variance             = 0.001
#                  Weighted Transformed Average  = 0.0006
#                  Weighted Transformed Variance = 0.989
# Setting up rotation matrices for variogram and search
# Working on realization number 0
#    currently on node 0
#    currently on node 1000
#    currently on node 2000
#    currently on node 3000
#    currently on node 4000
#    currently on node 5000
#    currently on node 6000
#    currently on node 7000
#    currently on node 8000
#    currently on node 9000
# Reassigning data to nodes
#
#  Realization 0: number   = 10000
#                                    mean     = -0.2198 (close to 0.0?)
#                                    variance = 0.8953 (close to gammabar(V,V)? approx. 1.0)
# sampy:  0.12033834727829126
# Applying Strategy for SGSIM model #5
# Number of good wells so far: 52
# [0.15612876 0.18412938 0.14669515 0.14942234 0.15510452 0.15420596
#  0.15440298 0.17678703 0.20413875 0.14696983 0.15443593 0.18312661
#  0.15623126 0.14875672 0.15639977 0.15446086 0.15184634 0.17724552
#  0.16830748 0.15255321 0.15474004 0.1460789  0.14958946 0.15150831
#  0.1730967  0.15809201 0.18290151 0.1544018  0.14944018 0.18225688
#  0.16957248 0.16077699 0.15442452 0.17216841 0.15644068 0.15175644
#  0.14628316 0.15206708 0.19490354 0.17683581 0.17234634 0.17226562
#  0.17216841 0.16004618 0.15138484 0.16953751 0.16669915 0.14988642
#  0.19293363 0.14942875 0.14607582 0.18580193]
# Text(0.5, 1.0, 'Uncertainty in Mean Porosity of well locations')

# %%
#well samples from both anisotropic methods 
constant_aniso = pd.DataFrame(wells_threshold_aniso)
journellian_aniso = pd.DataFrame(goodwells_aniso)


bins1 = 60

ax1 = plt.subplot(2,1,1)
n, bins,patches = ax1.hist(constant_aniso,bins1,facecolor = 'orange',density=True,
                           label = 'Constant Drill Locations Porosity Samples with Threshold - Anisotropic ')
n, bins,patches = ax1.hist(journellian_aniso,bins1,facecolor = 'blue',density=True,alpha = .5,
                           label = 'Strategized Drill Locations Porosity Samples - Anisotropic')

#ax1.set_xlim([.178,.2])
ax1.set_xlabel('Good Wells Porosity' )
ax1.set_ylabel('Count')
ax1.set_title('Constant Drill locations vs Strategized Drill Locations: Well Samples with Anisotrpoic Variogram')
ax1.legend() 

print('Constant Drill Location Statistics: \n', constant_aniso.describe())
print('Strategized Drill Location Statistics: \n', journellian_aniso.describe())

bins2 = 30
ax2 = plt.subplot(2,1,2)
n, bins,patches = ax2.hist(mean_por_standard_threshold_aniso,bins2,facecolor = 'orange',density=True,
                           label = 'Constant Drill Locations Mean Porosity with Threshold - Anisotrpoic')
n, bins,patches = ax2.hist(mean_por_aniso,bins2,facecolor = 'blue',density=True,alpha = .5,
                           label = 'Strategized Drill Locations Mean Porosity - Anisotrpoic')

#ax2.set_xlim([.185,.194])
ax2.set_xlabel('Mean Porosity')
ax2.set_ylabel('Count')
ax2.set_title('Constant Drill locations vs Strategized Drill Locations: Uncertainty in Mean Porosity with Anisotropic Variogram')
ax2.legend() 

mean_por_standard_threshold_aniso_df = pd.DataFrame(mean_por_standard_threshold_aniso)
mean_por_aniso_df = pd.DataFrame(mean_por_aniso)
print('Constant Drill Location Uncertainty Statistics: \n', mean_por_standard_threshold_aniso_df.describe())
print('Strategized Drill Location Uncertainty Statistics: \n', mean_por_aniso_df.describe())



plt.subplots_adjust(left=0.0, bottom=0.0, right=1.2, top=2.2, wspace=0.1, hspace=0.3)
# Out:
# Constant Drill Location Statistics:
#                 0
# count  42.000000
# mean    0.169422
# std     0.020627
# min     0.146081
# 25%     0.153427
# 50%     0.168593
# 75%     0.172919
# max     0.237029
# Strategized Drill Location Statistics:
#                 0
# count  52.000000
# mean    0.162640
# std     0.014629
# min     0.146076
# 25%     0.151694
# 50%     0.156180
# 75%     0.172286
# max     0.204139
# Constant Drill Location Uncertainty Statistics:
#                  0
# count  100.000000
# mean     0.169128
# std      0.002953
# min      0.163195
# 25%      0.166969
# 50%      0.169063
# 75%      0.171000
# max      0.176320
# Strategized Drill Location Uncertainty Statistics:
#                  0
# count  100.000000
# mean     0.162534
# std      0.002016
# min      0.157776
# 25%      0.161097
# 50%      0.162849
# 75%      0.164008
# max      0.166458

# %% [markdown]
# ## Conclusion
#
# We see that with an anisotrpic SGSIM model, our constant drilling location Journellian bootstrap sampling method (say method 1) yields higher mean porosity than our strategized drilling location Journellian bootstrap samplling method (say method 2).  Method 2 shows a more narrow distribution of uncertainty in mean porosity and yields more good wells than Method 1. We can attribute this to the way method 2 takes samples. Once a good well is located, the subequent well is bounded by the elliptical region so our model tracks the spatially correlated streaks of high porosity values which would yield highly similar porosity values. Method 1 instead accepts all high porosity values it happens to find at random drilling locations which may belong to mulitple high porosity streaks thus resulting in more uncertainty in mean porosity.
#
# In conclusion, once method 2 finds a good well sample, it will tend to follow the spatial pattern of high porosity with low uncertainty in the mean of these values as they are spatially correlated with each other.

# %% [markdown]
# #### Comments
#
# The Texas Center for Geostatistics has many other demonstrations on the basics of working with DataFrames, ndarrays, univariate statistics, plotting data, declustering, data transformations, trend modeling and many other workflows available [here](https://github.com/GeostatsGuy/PythonNumericalDemos), along with a package for geostatistics in Python called [GeostatsPy](https://github.com/GeostatsGuy/GeostatsPy).
#
# We hope this was helpful,
#
# *Adrian* and *Michael*
#
# ***
#
# #### More on Michael Pyrcz and the Texas Center for Data Analytics and Geostatistics:
#
# ### Michael Pyrcz, Associate Professor, University of Texas at Austin
# *Novel Data Analytics, Geostatistics and Machine Learning Subsurface Solutions*
#
# With over 17 years of experience in subsurface consulting, research and development, Michael has returned to academia driven by his passion for teaching and enthusiasm for enhancing engineers' and geoscientists' impact in subsurface resource development.
#
# For more about Michael check out these links:
#
# #### [Twitter](https://twitter.com/geostatsguy) | [GitHub](https://github.com/GeostatsGuy) | [Website](http://michaelpyrcz.com) | [GoogleScholar](https://scholar.google.com/citations?user=QVZ20eQAAAAJ&hl=en&oi=ao) | [Book](https://www.amazon.com/Geostatistical-Reservoir-Modeling-Michael-Pyrcz/dp/0199731446) | [YouTube](https://www.youtube.com/channel/UCLqEr-xV-ceHdXXXrTId5ig)  | [LinkedIn](https://www.linkedin.com/in/michael-pyrcz-61a648a1)
#
# #### Want to Work Together?
#
# I hope this content is helpful to those that want to learn more about subsurface modeling, data analytics and machine learning. Students and working professionals are welcome to participate.
#
# * Want to invite me to visit your company for training, mentoring, project review, workflow design and / or consulting? I'd be happy to drop by and work with you!
#
# * Interested in partnering, supporting my graduate student research or my Subsurface Data Analytics and Machine Learning consortium (co-PIs including Profs. Foster, Torres-Verdin and van Oort)? My research combines data analytics, stochastic modeling and machine learning theory with practice to develop novel methods and workflows to add value. We are solving challenging subsurface problems!
#
# * I can be reached at mpyrcz@austin.utexas.edu.
#
# I'm always happy to discuss,
#
# *Michael*
#
# Michael Pyrcz, Ph.D., P.Eng. Associate Professor The Hildebrand Department of Petroleum and Geosystems Engineering, Bureau of Economic Geology, The Jackson School of Geosciences, The University of Texas at Austin
#
# #### More Resources Available at: [Twitter](https://twitter.com/geostatsguy) | [GitHub](https://github.com/GeostatsGuy) | [Website](http://michaelpyrcz.com) | [GoogleScholar](https://scholar.google.com/citations?user=QVZ20eQAAAAJ&hl=en&oi=ao) | [Book](https://www.amazon.com/Geostatistical-Reservoir-Modeling-Michael-Pyrcz/dp/0199731446) | [YouTube](https://www.youtube.com/channel/UCLqEr-xV-ceHdXXXrTId5ig)  | [LinkedIn](https://www.linkedin.com/in/michael-pyrcz-61a648a1)
